# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Description" data-toc-modified-id="Description-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Description</a></span></li><li><span><a href="#Imports" data-toc-modified-id="Imports-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#Delete-Old-database" data-toc-modified-id="Delete-Old-database-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Delete Old database</a></span></li><li><span><a href="#Load-the-database" data-toc-modified-id="Load-the-database-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Load the database</a></span></li><li><span><a href="#Make-Table-Names-Plural" data-toc-modified-id="Make-Table-Names-Plural-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Make Table Names Plural</a></span></li><li><span><a href="#Delete-Unwanted-Tables" data-toc-modified-id="Delete-Unwanted-Tables-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Delete Unwanted Tables</a></span></li><li><span><a href="#Create-New-Tables" data-toc-modified-id="Create-New-Tables-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Create New Tables</a></span></li><li><span><a href="#Rename-Tables-(Make-Plurals)" data-toc-modified-id="Rename-Tables-(Make-Plurals)-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Rename Tables (Make Plurals)</a></span></li><li><span><a href="#Pandas-dataframes" data-toc-modified-id="Pandas-dataframes-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Pandas dataframes</a></span></li><li><span><a href="#Order-Table-is-Corrupted,-Create-new-table" data-toc-modified-id="Order-Table-is-Corrupted,-Create-new-table-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Order Table is Corrupted, Create new table</a></span></li><li><span><a href="#Peek-at-dataframes" data-toc-modified-id="Peek-at-dataframes-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Peek at dataframes</a></span></li><li><span><a href="#PySpark-dataframes" data-toc-modified-id="PySpark-dataframes-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>PySpark dataframes</a></span></li><li><span><a href="#Advanced-SQL-Questions" data-toc-modified-id="Advanced-SQL-Questions-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Advanced SQL Questions</a></span><ul class="toc-item"><li><span><a href="#32.-High-value-customers" data-toc-modified-id="32.-High-value-customers-13.1"><span class="toc-item-num">13.1&nbsp;&nbsp;</span>32. High-value customers</a></span></li><li><span><a href="#33.-High-value-customers---total-orders" data-toc-modified-id="33.-High-value-customers---total-orders-13.2"><span class="toc-item-num">13.2&nbsp;&nbsp;</span>33. High-value customers - total orders</a></span></li><li><span><a href="#34.-High-value-customers---with-discount" data-toc-modified-id="34.-High-value-customers---with-discount-13.3"><span class="toc-item-num">13.3&nbsp;&nbsp;</span>34. High-value customers - with discount</a></span></li><li><span><a href="#35.-Month-end-orders" data-toc-modified-id="35.-Month-end-orders-13.4"><span class="toc-item-num">13.4&nbsp;&nbsp;</span>35. Month-end orders</a></span></li><li><span><a href="#36.-Orders-with-many-line-items" data-toc-modified-id="36.-Orders-with-many-line-items-13.5"><span class="toc-item-num">13.5&nbsp;&nbsp;</span>36. Orders with many line items</a></span></li><li><span><a href="#37.-Orders---random-assortment" data-toc-modified-id="37.-Orders---random-assortment-13.6"><span class="toc-item-num">13.6&nbsp;&nbsp;</span>37. Orders - random assortment</a></span></li><li><span><a href="#38.-Orders---accidental-double-entry" data-toc-modified-id="38.-Orders---accidental-double-entry-13.7"><span class="toc-item-num">13.7&nbsp;&nbsp;</span>38. Orders - accidental double-entry</a></span></li><li><span><a href="#39.-Orders---accidental-double-entry-details" data-toc-modified-id="39.-Orders---accidental-double-entry-details-13.8"><span class="toc-item-num">13.8&nbsp;&nbsp;</span>39. Orders - accidental double-entry details</a></span></li><li><span><a href="#40.-Orders---accidental-double-entry" data-toc-modified-id="40.-Orders---accidental-double-entry-13.9"><span class="toc-item-num">13.9&nbsp;&nbsp;</span>40. Orders - accidental double-entry</a></span></li><li><span><a href="#41.-Late-orders" data-toc-modified-id="41.-Late-orders-13.10"><span class="toc-item-num">13.10&nbsp;&nbsp;</span>41. Late orders</a></span></li><li><span><a href="#42.-Late-orders---which-employees?" data-toc-modified-id="42.-Late-orders---which-employees?-13.11"><span class="toc-item-num">13.11&nbsp;&nbsp;</span>42. Late orders - which employees?</a></span></li><li><span><a href="#43.-Late-orders-vs.-total-orders" data-toc-modified-id="43.-Late-orders-vs.-total-orders-13.12"><span class="toc-item-num">13.12&nbsp;&nbsp;</span>43. Late orders vs. total orders</a></span></li><li><span><a href="#45.-Late-orders-vs.-total-orders---fix-null" data-toc-modified-id="45.-Late-orders-vs.-total-orders---fix-null-13.13"><span class="toc-item-num">13.13&nbsp;&nbsp;</span>45. Late orders vs. total orders - fix null</a></span></li><li><span><a href="#46.-Late-orders-vs.-total-orders---percentage" data-toc-modified-id="46.-Late-orders-vs.-total-orders---percentage-13.14"><span class="toc-item-num">13.14&nbsp;&nbsp;</span>46. Late orders vs. total orders - percentage</a></span></li><li><span><a href="#47.-Late-orders-vs.-total-orders---fix-decimal" data-toc-modified-id="47.-Late-orders-vs.-total-orders---fix-decimal-13.15"><span class="toc-item-num">13.15&nbsp;&nbsp;</span>47. Late orders vs. total orders - fix decimal</a></span></li><li><span><a href="#48.-Customer-grouping" data-toc-modified-id="48.-Customer-grouping-13.16"><span class="toc-item-num">13.16&nbsp;&nbsp;</span>48. Customer grouping</a></span></li><li><span><a href="#49.-Customer-grouping---fix-null" data-toc-modified-id="49.-Customer-grouping---fix-null-13.17"><span class="toc-item-num">13.17&nbsp;&nbsp;</span>49. Customer grouping - fix null</a></span></li><li><span><a href="#50.-Customer-grouping-with-percentage" data-toc-modified-id="50.-Customer-grouping-with-percentage-13.18"><span class="toc-item-num">13.18&nbsp;&nbsp;</span>50. Customer grouping with percentage</a></span></li><li><span><a href="#51.-Customer-grouping---flexible" data-toc-modified-id="51.-Customer-grouping---flexible-13.19"><span class="toc-item-num">13.19&nbsp;&nbsp;</span>51. Customer grouping - flexible</a></span></li><li><span><a href="#52.-Countries-with-suppliers-or-customers" data-toc-modified-id="52.-Countries-with-suppliers-or-customers-13.20"><span class="toc-item-num">13.20&nbsp;&nbsp;</span>52. Countries with suppliers or customers</a></span></li><li><span><a href="#53.-Countries-with-suppliers-or-customers,-version-2" data-toc-modified-id="53.-Countries-with-suppliers-or-customers,-version-2-13.21"><span class="toc-item-num">13.21&nbsp;&nbsp;</span>53. Countries with suppliers or customers, version 2</a></span></li><li><span><a href="#54.-Countries-with-suppliers-or-customers---version-3" data-toc-modified-id="54.-Countries-with-suppliers-or-customers---version-3-13.22"><span class="toc-item-num">13.22&nbsp;&nbsp;</span>54. Countries with suppliers or customers - version 3</a></span></li><li><span><a href="#55.-First-order-in-each-country" data-toc-modified-id="55.-First-order-in-each-country-13.23"><span class="toc-item-num">13.23&nbsp;&nbsp;</span>55. First order in each country</a></span></li><li><span><a href="#56.-Customers-with-multiple-orders-in-5-day-period" data-toc-modified-id="56.-Customers-with-multiple-orders-in-5-day-period-13.24"><span class="toc-item-num">13.24&nbsp;&nbsp;</span>56. Customers with multiple orders in 5 day period</a></span></li><li><span><a href="#57.-Customers-with-multiple-orders-in-5-day-period,-version-2" data-toc-modified-id="57.-Customers-with-multiple-orders-in-5-day-period,-version-2-13.25"><span class="toc-item-num">13.25&nbsp;&nbsp;</span>57. Customers with multiple orders in 5 day period, version 2</a></span></li></ul></li><li><span><a href="#Time-Taken" data-toc-modified-id="Time-Taken-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Time Taken</a></span></li></ul></div>

# %% [markdown]
# # Description
# This tutorial is based on the book "SQL Practice Problems".
# The book uses fake database created by Microsoft called Northwind and modifies
# it by adding new entries. The book provides the answer on MS SQL server 2016.
#
#
# - [book link](https://www.amazon.com/SQL-Practice-Problems-learn-doing-ebook/dp/B01N41VQFO)
# - [Entity Relation](https://docs.yugabyte.com/latest/sample-data/northwind/)
# - [Pyspark sql functions](https://spark.apache.org/docs/latest/api/sql/index.html)
#
# **Notes:**
# - The table Order is corrupt, can not be deleted.
# - I will create Orders table from another script.
# - The table customercustomerdemo is empty.
# - The table CustomerDemographic is empty.
# - The Order Table has orderdate between 1996-07-04 to 1998-05-06
#   Only the year 1997 has the full year data.
# - In this book, percentage is between 0 to 1 not 0 to 100.
#
#
# The Order data is corrupted. But it can be recreated using Yugabyte github.
# - [create table orders](https://github.com/yugabyte/yugabyte-db/blob/master/sample/northwind_ddl.sql)
# - [insert into orders](https://github.com/yugabyte/yugabyte-db/blob/master/sample/northwind_data.sql)
#
#
# ![](images/northwind_entity_relation.png)

# %% [markdown]
# # Imports

# %%
import time
time_start_notebook = time.time()

from datetime import datetime
from dateutil.relativedelta import relativedelta
# last_year = datetime.now() - relativedelta(years=1)

import numpy as np
import pandas as pd

import sqlite3
sqlite3.sqlite_version # sqlite database version 3.29
sqlite3.version # python module version
# Out:
# '2.6.0'

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
# Jupyter notebook settings for pandas
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# # Delete Old database

# %%
import os
import shutil

old = 'data/NorthwindNew.sqlite'
src = 'data/Northwind_orig.sqlite'
if os.path.isfile(old):
    os.remove(old)
    shutil.copyfile(src,old)
else:
    shutil.copyfile(src,old)

# %% [markdown]
# # Load the database

# %%
database = 'data/NorthwindNew.sqlite'

conn = sqlite3.connect(database)
cur = conn.cursor() # cur.exectute(query) then cur.commit() then cur.close()

# %% [markdown]
# # Make Table Names Plural

# %%
tables = pd.read_sql("select * from sqlite_master where type='table';", conn)
tables
# Out:
#      type                  name              tbl_name  rootpage  \
# 0   table              Employee              Employee         2
# 1   table              Category              Category         3
# 2   table              Customer              Customer         4
# 3   table               Shipper               Shipper         8
# 4   table              Supplier              Supplier         9
# 5   table               Product               Product        12
# 6   table           OrderDetail           OrderDetail        14
# 7   table  CustomerCustomerDemo  CustomerCustomerDemo        16
# 8   table   CustomerDemographic   CustomerDemographic        18
# 9   table                Region                Region        21
# 10  table             Territory             Territory        22
# 11  table     EmployeeTerritory     EmployeeTerritory        24
# 12  table                 Order                 Order        11
# 13  table                orders                orders       155
#
# ...

# %%
# single table info
pd.read_sql("pragma table_info('Employee')",conn)
# Out:
#     cid             name           type  notnull dflt_value  pk
# 0     0               Id        INTEGER        0       None   1
# 1     1         LastName  VARCHAR(8000)        0       None   0
# 2     2        FirstName  VARCHAR(8000)        0       None   0
# 3     3            Title  VARCHAR(8000)        0       None   0
# 4     4  TitleOfCourtesy  VARCHAR(8000)        0       None   0
# 5     5        BirthDate  VARCHAR(8000)        0       None   0
# 6     6         HireDate  VARCHAR(8000)        0       None   0
# 7     7          Address  VARCHAR(8000)        0       None   0
# 8     8             City  VARCHAR(8000)        0       None   0
# 9     9           Region  VARCHAR(8000)        0       None   0
# 10   10       PostalCode  VARCHAR(8000)        0       None   0
# 11   11          Country  VARCHAR(8000)        0       None   0
# 12   12        HomePhone  VARCHAR(8000)        0       None   0
# 13   13        Extension  VARCHAR(8000)        0       None   0
# ...

# %%
table_names = tables['name'].to_numpy()
table_names
# Out:
# array(['Employee', 'Category', 'Customer', 'Shipper', 'Supplier',
#        'Product', 'OrderDetail', 'CustomerCustomerDemo',
#        'CustomerDemographic', 'Region', 'Territory', 'EmployeeTerritory',
#        'Order', 'orders'], dtype=object)

# %%
for t in table_names:
    try:
        dfx = pd.read_sql(f"""SELECT * from {t} limit 1""", conn)
        print(t,f" shape: {dfx.shape}")
        if dfx.shape[0] == 0:
            print(f'Empty Table: {t}')
        display(pd.read_sql(f"""SELECT * from {t} limit 1""", conn))
        print()
            
    except:
        print(f'Corrupted Table: {t}\n\n')
# Out:
# Employee  shape: (1, 18)
#    Id LastName FirstName                 Title TitleOfCourtesy   BirthDate  \
# 0   1  Davolio     Nancy  Sales Representative             Ms.  1948-12-08
#
#      HireDate                     Address     City Region PostalCode Country  \
# 0  1992-05-01  507 - 20th Ave. E. Apt. 2A  Seattle     WA      98122     USA
#
#         HomePhone Extension Photo  \
# 0  (206) 555-9857      5467  None
#
#                                                Notes  ReportsTo  \
# 0  Education includes a BA in psychology from Col...          2
#
#                               PhotoPath
# 0  http://accweb/emmployees/davolio.bmp
# Category  shape: (1, 3)
#    Id CategoryName                                  Description
# 0   1    Beverages  Soft drinks, coffees, teas, beers, and ales
# Customer  shape: (1, 11)
#       Id          CompanyName   ContactName          ContactTitle  \
# 0  ALFKI  Alfreds Futterkiste  Maria Anders  Sales Representative
#
# ...

# %% [markdown]
# # Delete Unwanted Tables

# %%
# The table Order is corrupt, can not be deleted.
bad_tables = ['Order','orders', 'CustomerCustomerDemo','CustomerDemographic']
for b in bad_tables:
    try:
        cur.execute(f"drop table if exists {b}")
    except:
        pass

# %%
tables = pd.read_sql("""SELECT *
                        FROM sqlite_master
                        WHERE type='table';""", conn)
tables
# Out:
#      type               name           tbl_name  rootpage  \
# 0   table           Employee           Employee         2
# 1   table           Category           Category         3
# 2   table           Customer           Customer         4
# 3   table            Shipper            Shipper         8
# 4   table           Supplier           Supplier         9
# 5   table            Product            Product        12
# 6   table        OrderDetail        OrderDetail        14
# 7   table             Region             Region        21
# 8   table          Territory          Territory        22
# 9   table  EmployeeTerritory  EmployeeTerritory        24
# 10  table              Order              Order        11
#
#                                                   sql
# 0   CREATE TABLE "Employee" \n(\n  "Id" INTEGER PR...
# 1   CREATE TABLE "Category" \n(\n  "Id" INTEGER PR...
# 2   CREATE TABLE "Customer" \n(\n  "Id" VARCHAR(80...
# ...

# %% [markdown]
# # Create New Tables

# %%
q = tables.loc[tables['name']=='Employee','sql'].to_numpy()[0]

print(q)
# Out:
# CREATE TABLE "Employee"
# (
#   "Id" INTEGER PRIMARY KEY,
#   "LastName" VARCHAR(8000) NULL,
#   "FirstName" VARCHAR(8000) NULL,
#   "Title" VARCHAR(8000) NULL,
#   "TitleOfCourtesy" VARCHAR(8000) NULL,
#   "BirthDate" VARCHAR(8000) NULL,
#   "HireDate" VARCHAR(8000) NULL,
#   "Address" VARCHAR(8000) NULL,
#   "City" VARCHAR(8000) NULL,
#   "Region" VARCHAR(8000) NULL,
#   "PostalCode" VARCHAR(8000) NULL,
#   "Country" VARCHAR(8000) NULL,
#   "HomePhone" VARCHAR(8000) NULL,
#   "Extension" VARCHAR(8000) NULL,
#   "Photo" BLOB NULL,
#   "Notes" VARCHAR(8000) NULL,
#   "ReportsTo" INTEGER NULL,
#   "PhotoPath" VARCHAR(8000) NULL
# )

# %%
q2 = q.replace('Employee','MyEmployee').replace('Id','EmployeeId')
cur.execute(q2)

# %%
tables = pd.read_sql("""select * from sqlite_master
                        where type='table';""", conn)
tables
# Out:
#      type               name           tbl_name  rootpage  \
# 0   table           Employee           Employee         2
# 1   table           Category           Category         3
# 2   table           Customer           Customer         4
# 3   table            Shipper            Shipper         8
# 4   table           Supplier           Supplier         9
# 5   table            Product            Product        12
# 6   table        OrderDetail        OrderDetail        14
# 7   table             Region             Region        21
# 8   table          Territory          Territory        22
# 9   table  EmployeeTerritory  EmployeeTerritory        24
# 10  table              Order              Order        11
# 11  table         MyEmployee         MyEmployee        16
#
#                                                   sql
# 0   CREATE TABLE "Employee" \n(\n  "Id" INTEGER PR...
# 1   CREATE TABLE "Category" \n(\n  "Id" INTEGER PR...
# ...

# %%
pd.read_sql(f"""SELECT * from MyEmployee""", conn)
# its an empty table.
# Out:
# Empty DataFrame
# Columns: [EmployeeId, LastName, FirstName, Title, TitleOfCourtesy, BirthDate, HireDate, Address, City, Region, PostalCode, Country, HomePhone, Extension, Photo, Notes, ReportsTo, PhotoPath]
# Index: []

# %%
cursor = conn.execute('select * from Employee')
colsOld = [desc[0] for desc in cursor.description]
print(colsOld)
# Out:
# ['Id', 'LastName', 'FirstName', 'Title', 'TitleOfCourtesy', 'BirthDate', 'HireDate', 'Address', 'City', 'Region', 'PostalCode', 'Country', 'HomePhone', 'Extension', 'Photo', 'Notes', 'ReportsTo', 'PhotoPath']

# %%
cursor = conn.execute('select * from MyEmployee')
colsNew = [desc[0] for desc in cursor.description]
print(colsNew)
# Out:
# ['EmployeeId', 'LastName', 'FirstName', 'Title', 'TitleOfCourtesy', 'BirthDate', 'HireDate', 'Address', 'City', 'Region', 'PostalCode', 'Country', 'HomePhone', 'Extension', 'Photo', 'Notes', 'ReportsTo', 'PhotoPath']

# %%
cur = conn.execute('select * from MyEmployee')
for old,new in zip(colsOld,colsNew):
    q = f"UPDATE MyEmployee SET {new} = (SELECT {old} FROM Employee)"
    cur.execute(q)

# %%
pd.read_sql(f"""SELECT Id from Employee limit 2""", conn)
# Out:
#    Id
# 0   1
# 1   2

# %%
pd.read_sql(f"""SELECT * from MyEmployee limit 2""", conn)
# Out:
# Empty DataFrame
# Columns: [EmployeeId, LastName, FirstName, Title, TitleOfCourtesy, BirthDate, HireDate, Address, City, Region, PostalCode, Country, HomePhone, Extension, Photo, Notes, ReportsTo, PhotoPath]
# Index: []

# %%
cursor = conn.cursor()
try:
    cursor.execute("drop table if exists MyEmployee")
except:
    pass

# %% [markdown]
# # Rename Tables (Make Plurals)

# %%
tables = pd.read_sql("""SELECT *
                        FROM sqlite_master
                        WHERE type='table';""", conn)

tables['name'].to_numpy()
# Out:
# array(['Employee', 'Category', 'Customer', 'Shipper', 'Supplier',
#        'Product', 'OrderDetail', 'Region', 'Territory',
#        'EmployeeTerritory', 'Order'], dtype=object)

# %%
names = ['Employee',  'Customer', 'Shipper', 'Supplier',
         'Product','OrderDetail', 'Region']

namesNew = ['Employees',  'Customers', 'Shippers', 'Suppliers',
         'Products','OrderDetails', 'Regions']

names2 = ['Category','Territory','EmployeeTerritory']
names2New = ['Categories','Territories','EmployeeTerritories']

# %%
for old,new in zip(names,namesNew):
    q = f"alter table {old} rename to {new}"
    cur.execute(q)
    
for old,new in zip(names2,names2New):
    q = f"alter table {old} rename to {new}"
    cur.execute(q)

# %%
tables = pd.read_sql("""SELECT *
                        FROM sqlite_master
                        WHERE type='table';""", conn)

tables['name'].to_numpy()
# Out:
# array(['Employees', 'Categories', 'Customers', 'Shippers', 'Suppliers',
#        'Products', 'OrderDetails', 'Regions', 'Territories',
#        'EmployeeTerritories', 'Order'], dtype=object)

# %% [markdown]
# # Pandas dataframes

# %%
tables['name'].to_numpy()
# Out:
# array(['Employees', 'Categories', 'Customers', 'Shippers', 'Suppliers',
#        'Products', 'OrderDetails', 'Regions', 'Territories',
#        'EmployeeTerritories', 'Order'], dtype=object)

# %%
Employees = pd.read_sql("""SELECT * from Employees""", conn)
Categories = pd.read_sql("""SELECT * from Categories""", conn)
Customers = pd.read_sql("""SELECT * from Customers""", conn) 
Shippers = pd.read_sql("""SELECT * from Shippers""", conn)
Suppliers = pd.read_sql("""SELECT * from Suppliers""", conn) 

Products = pd.read_sql("""SELECT * from Products""", conn)
OrderDetails = pd.read_sql("""SELECT * from OrderDetails""", conn)

Regions = pd.read_sql("""SELECT * from Regions""", conn)
Territories = pd.read_sql("""SELECT * from Territories""", conn)

EmployeeTerritories = pd.read_sql("""SELECT * from EmployeeTerritories""", conn)

# %% [markdown]
# # Order Table is Corrupted, Create new table
# - https://github.com/yugabyte/yugabyte-db/blob/master/sample/northwind_data.sql

# %%
cur.execute(
"""
CREATE TABLE orders (
    orderid smallint NOT NULL,
    customerid bpchar,
    employeeid smallint,
    orderdate date,
    requireddate date,
    shippeddate date,
    shipvia smallint,
    freight real,
    shipname character varying(40),
    shipaddress character varying(60),
    shipcity character varying(15),
    shipregion character varying(15),
    shippostalcode character varying(10),
    shipcountry character varying(15)
)
""")

# %%
# !head -n 2 data/orders_data.sql
# Out:
# INSERT INTO orders VALUES (10248, 'VINET', 5, '1996-07-04', '1996-08-01', '1996-07-16', 3, 32.3800011, 'Vins et alcools Chevalier', '59 rue de l''Abbaye', 'Reims', NULL, '51100', 'France');
# INSERT INTO orders VALUES (10249, 'TOMSP', 6, '1996-07-05', '1996-08-16', '1996-07-10', 1, 11.6099997, 'Toms Spezialitäten', 'Luisenstr. 48', 'Münster', NULL, '44087', 'Germany');

# %%
with open('data/orders_data.sql') as fi:
    for line in fi.readlines():
        cur.execute(line)
        
conn.commit()

# %%
Orders = pd.read_sql("""SELECT * from Orders""", conn)
Orders.head(2)
# Out:
#    orderid customerid  employeeid   orderdate requireddate shippeddate  \
# 0    10248      VINET           5  1996-07-04   1996-08-01  1996-07-16
# 1    10249      TOMSP           6  1996-07-05   1996-08-16  1996-07-10
#
#    shipvia    freight                   shipname         shipaddress shipcity  \
# 0        3  32.380001  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
# 1        1  11.610000         Toms Spezialitäten       Luisenstr. 48  Münster
#
#   shipregion shippostalcode shipcountry
# 0       None          51100      France
# 1       None          44087     Germany

# %%
Orders['orderdate'] = pd.to_datetime(Orders['orderdate'])
Orders['requireddate'] = pd.to_datetime(Orders['requireddate'])
Orders['shippeddate'] = pd.to_datetime(Orders['shippeddate'])

Orders.dtypes
# Out:
# orderid                    int64
# customerid                object
# employeeid                 int64
# orderdate         datetime64[ns]
# requireddate      datetime64[ns]
# shippeddate       datetime64[ns]
# shipvia                    int64
# freight                  float64
# shipname                  object
# shipaddress               object
# shipcity                  object
# shipregion                object
# shippostalcode            object
# shipcountry               object
# dtype: object

# %% [markdown]
# # Peek at dataframes

# %%
dfs_names = ['Employees', 'Categories','Customers',
             'Shippers','Suppliers','Orders',
             'Products','OrderDetails',
             'Regions', 'Territories', 'EmployeeTerritories']

dfs = [ Employees, Categories,Customers,Shippers,Suppliers,
        Orders, Products,OrderDetails,
       Regions, Territories, EmployeeTerritories]

for df_name, df in zip(dfs_names,dfs):
    print(df_name, df.shape)
    display(df.head(2))
# Out:
# Employees (9, 18)
#    Id LastName FirstName                  Title TitleOfCourtesy   BirthDate  \
# 0   1  Davolio     Nancy   Sales Representative             Ms.  1948-12-08
# 1   2   Fuller    Andrew  Vice President, Sales             Dr.  1952-02-19
#
#      HireDate                     Address     City Region PostalCode Country  \
# 0  1992-05-01  507 - 20th Ave. E. Apt. 2A  Seattle     WA      98122     USA
# 1  1992-08-14          908 W. Capital Way   Tacoma     WA      98401     USA
#
#         HomePhone Extension Photo  \
# 0  (206) 555-9857      5467  None
# 1  (206) 555-9482      3457  None
#
#                                                Notes  ReportsTo  \
# 0  Education includes a BA in psychology from Col...        2.0
# 1  Andrew received his BTS commercial in 1974 and...        NaN
#
#                               PhotoPath
# 0  http://accweb/emmployees/davolio.bmp
# 1   http://accweb/emmployees/fuller.bmp
# Categories (8, 3)
# ...

# %% [markdown]
# # PySpark dataframes

# %%
# pyspark
import pyspark
spark = pyspark.sql\
          .SparkSession\
          .builder\
          .appName('bhishan')\
          .getOrCreate()

# sql
from pyspark.sql.functions import col as _col
from pyspark.sql.functions import udf

# @udf("integer") def myfunc(x,y): return x - y
# stddev format_number date_format, dayofyear, when
from pyspark.sql import functions as F
from pyspark.sql.window import Window
from pyspark.sql.functions import (mean as _mean, min as _min,
                                   max as _max, avg as _avg,
                                   when as _when
                                  )

from pyspark.sql.types import *
from pyspark import SparkConf, SparkContext, SQLContext

sc = spark.sparkContext
sqlContext = SQLContext(sc)
# spark_df = sqlContext.createDataFrame(pandas_df,schema)

# %%
def spark_df_from_pandas(pandas_df):
    df_dtype = pandas_df.dtypes.astype(str).reset_index()
    df_dtype.columns = ['column','dtype']

    mapping = {'int64'  : 'IntegerType()',
               'float64': 'DoubleType()',
               'bool'   : 'BooleanType()',
               'object' : 'StringType()',
               'datetime64[ns]': 'DateType()',
              }

    df_dtype['dtype'] = df_dtype['dtype'].map(mapping)
    df_dtype['schema'] = "    StructField('" +\
                         df_dtype['column'] + "'," +\
                         df_dtype['dtype'] + ",True),"

    head = 'StructType([\n'
    body = '\n'.join(df_dtype['schema'])
    tail = '\n    ])'

    schema = head + body + tail
    spark_df = sqlContext.createDataFrame(pandas_df, eval(schema))
    return spark_df

# %%
sEmployees = spark_df_from_pandas(Employees)
sEmployees.createOrReplaceTempView("Employees")

sCategories = spark_df_from_pandas(Categories)
sCategories.createOrReplaceTempView("Categories")

sCustomers = spark_df_from_pandas(Customers)
sCustomers.createOrReplaceTempView("Customers")

sShippers = spark_df_from_pandas(Shippers)
sShippers.createOrReplaceTempView("Shippers")

sSuppliers = spark_df_from_pandas(Suppliers)
sSuppliers.createOrReplaceTempView("Suppliers")

sOrders = spark_df_from_pandas(Orders)
sOrders.createOrReplaceTempView("Orders")

sProducts = spark_df_from_pandas(Products)
sProducts.createOrReplaceTempView("Products")

sOrderDetails = spark_df_from_pandas(OrderDetails)
sOrderDetails.createOrReplaceTempView("OrderDetails")

sRegions = spark_df_from_pandas(Regions)
sRegions.createOrReplaceTempView("Regions")

sTerritories = spark_df_from_pandas(Territories)
sTerritories.createOrReplaceTempView("Territories")

sEmployeeTerritories = spark_df_from_pandas(EmployeeTerritories)
sEmployeeTerritories.createOrReplaceTempView("EmployeeTerritories")

# %% [markdown]
# # Advanced SQL Questions

# %% [markdown]
# ## 32. High-value customers
# We want to send all of our high-value customers a
# special VIP gift. We're defining high-value
# customers as those who've made at least 1 order with
# a total value (not including the discount) equal to
# $10,000 or more. We only want to consider orders
# made in the year 1997.

# %%
OrderDetails.head(2)
# Out:
#          Id  OrderId  ProductId  UnitPrice  Quantity  Discount
# 0  10248/11    10248         11       14.0        12       0.0
# 1  10248/42    10248         42        9.8        10       0.0

# %%
OrderDetails['Discount'].max() # discount is percentage.
# Out:
# 0.25

# %%
OrderDetails['OrderAmount'] = (OrderDetails['UnitPrice']  
                               * OrderDetails['Quantity']
                               * (1 - OrderDetails['Discount'])
                              )

OrderDetails.head(2)
# Out:
#          Id  OrderId  ProductId  UnitPrice  Quantity  Discount  OrderAmount
# 0  10248/11    10248         11       14.0        12       0.0        168.0
# 1  10248/42    10248         42        9.8        10       0.0         98.0

# %%
# find total order amount per orderid
OrderDetails['TotalOrderAmount'] = OrderDetails.groupby('OrderId')['OrderAmount'].transform('sum')
OrderDetails.head(2)
# Out:
#          Id  OrderId  ProductId  UnitPrice  Quantity  Discount  OrderAmount  \
# 0  10248/11    10248         11       14.0        12       0.0        168.0
# 1  10248/42    10248         42        9.8        10       0.0         98.0
#
#    TotalOrderAmount
# 0             440.0
# 1             440.0

# %%
Orders.head(2)
# Out:
#    orderid customerid  employeeid  orderdate requireddate shippeddate  \
# 0    10248      VINET           5 1996-07-04   1996-08-01  1996-07-16
# 1    10249      TOMSP           6 1996-07-05   1996-08-16  1996-07-10
#
#    shipvia    freight                   shipname         shipaddress shipcity  \
# 0        3  32.380001  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
# 1        1  11.610000         Toms Spezialitäten       Luisenstr. 48  Münster
#
#   shipregion shippostalcode shipcountry
# 0       None          51100      France
# 1       None          44087     Germany

# %%
Orders['orderdate'].agg([min,max])
# Out:
# min   1996-07-04
# max   1998-05-06
# Name: orderdate, dtype: datetime64[ns]

# %%
o1 = Orders.loc[Orders['orderdate'].dt.year==1997,['orderid','customerid']]
print(o1.shape)

o1.head(2)
# Out:
# (408, 2)
#      orderid customerid
# 152    10400      EASTC
# 153    10401      RATTC

# %%
# Look at yugabyte website ER diagram to find columns relation.
# required columns from book
# CustomerID CompanyName OrderID TotalOrderAmount
# Orders     Customers    Orders  CreatedFromOrderDetails

# note: shippers has company name but orders does not have shipper_id.

# %%
Customers.head(2)
# Out:
#       Id                         CompanyName   ContactName  \
# 0  ALFKI                 Alfreds Futterkiste  Maria Anders
# 1  ANATR  Ana Trujillo Emparedados y helados  Ana Trujillo
#
#            ContactTitle                        Address         City Region  \
# 0  Sales Representative                  Obere Str. 57       Berlin   None
# 1                 Owner  Avda. de la Constitución 2222  México D.F.   None
#
#   PostalCode  Country         Phone           Fax
# 0      12209  Germany   030-0074321   030-0076545
# 1      05021   Mexico  (5) 555-4729  (5) 555-3745

# %%
c1 = Customers[['Id','CompanyName']]
c1.head(2)
# Out:
#       Id                         CompanyName
# 0  ALFKI                 Alfreds Futterkiste
# 1  ANATR  Ana Trujillo Emparedados y helados

# %%
od1 = OrderDetails[['OrderId','TotalOrderAmount']]
od1 = od1[od1['TotalOrderAmount'] >= 10_000]
od1.head(2)
# Out:
#      OrderId  TotalOrderAmount
# 449    10417           11188.4
# 450    10417           11188.4

# %%
o1.head(2)
# Out:
#      orderid customerid
# 152    10400      EASTC
# 153    10401      RATTC

# %%
tmp = od1.merge(o1,left_on='OrderId',right_on='orderid',suffixes=['_od','_o'])
tmp = tmp.rename(columns={'Id':'Id_od'})
tmp.head(2)
# Out:
#    OrderId  TotalOrderAmount  orderid customerid
# 0    10417           11188.4    10417      SIMOB
# 1    10417           11188.4    10417      SIMOB

# %%
# OrderDetails['OrderAmount'] = (  OrderDetails['UnitPrice']
#                                - OrderDetails['Discount']
#                               ) * OrderDetails['Quantity'] 

# OrderDetails['TotalOrderAmount'] = OrderDetails.groupby('OrderId')\
#                                    ['OrderAmount'].transform('sum')

tmp = tmp.merge(c1,left_on='customerid',right_on='Id')
tmp = tmp.drop(['orderid','Id'],axis=1)
tmp = tmp[['customerid','CompanyName','OrderId','TotalOrderAmount']]
tmp = tmp.drop_duplicates()
tmp = tmp.sort_values('TotalOrderAmount',ascending=False)
tmp
# Out:
#    customerid                 CompanyName  OrderId  TotalOrderAmount
# 0       SIMOB               Simons bistro    10417           11188.4
# 4       RATTC  Rattlesnake Canyon Grocery    10479           10495.6
# 8       QUICK                  QUICK-Stop    10540           10191.7
# 12      QUICK                  QUICK-Stop    10691           10164.8

# %%
o1 = Orders.loc[Orders['orderdate'].dt.year==1997,['orderid','customerid']]
c1 = Customers[['Id','CompanyName']]
od1 = OrderDetails[['OrderId','TotalOrderAmount']]
od1 = od1[od1['TotalOrderAmount'] >= 10_000]

tmp = od1.merge(o1,left_on='OrderId',right_on='orderid',suffixes=['_od','_o'])
tmp = tmp.rename(columns={'Id':'Id_od'})

tmp = tmp.merge(c1,left_on='customerid',right_on='Id')
tmp = tmp.drop(['orderid','Id'],axis=1)
tmp = tmp[['customerid','CompanyName','OrderId','TotalOrderAmount']]
tmp = tmp.drop_duplicates()
tmp = tmp.sort_values('TotalOrderAmount',ascending=False)

del OrderDetails['OrderAmount']
del OrderDetails['TotalOrderAmount']

tmp
# Out:
#    customerid                 CompanyName  OrderId  TotalOrderAmount
# 0       SIMOB               Simons bistro    10417           11188.4
# 4       RATTC  Rattlesnake Canyon Grocery    10479           10495.6
# 8       QUICK                  QUICK-Stop    10540           10191.7
# 12      QUICK                  QUICK-Stop    10691           10164.8

# %%
OrderDetails.head(1)
# Out:
#          Id  OrderId  ProductId  UnitPrice  Quantity  Discount
# 0  10248/11    10248         11       14.0        12       0.0

# %%
pd.read_sql(f"""SELECT * from Customers limit 1""",conn)
# Out:
#       Id          CompanyName   ContactName          ContactTitle  \
# 0  ALFKI  Alfreds Futterkiste  Maria Anders  Sales Representative
#
#          Address    City Region PostalCode  Country        Phone          Fax
# 0  Obere Str. 57  Berlin   None      12209  Germany  030-0074321  030-0076545

# %%
pd.read_sql(f"""SELECT * from Orders limit 1""",conn)
# Out:
#    orderid customerid  employeeid   orderdate requireddate shippeddate  \
# 0    10248      VINET           5  1996-07-04   1996-08-01  1996-07-16
#
#    shipvia    freight                   shipname         shipaddress shipcity  \
# 0        3  32.380001  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
#
#   shipregion shippostalcode shipcountry
# 0       None          51100      France

# %%
pd.read_sql(f"""SELECT * from OrderDetails limit 1""",conn)
# Out:
#          Id  OrderId  ProductId  UnitPrice  Quantity  Discount
# 0  10248/11    10248         11         14        12       0.0

# %%
q = """
SELECT c.Id as CustomerID,
  c.CompanyName,
  o.OrderID,
  sum(od.UnitPrice * od.Quantity * (1 - od.Discount)) AS amount

FROM Customers AS c
  INNER JOIN Orders AS o
    ON c.Id = o.customerid
  INNER JOIN OrderDetails AS od
    ON o.orderid = od.OrderId

-- WHERE substr(o.orderdate,1,4) = '1997'
WHERE o.orderdate >= date('1997-01-01') and o.orderdate < date('1998-01-01')

GROUP BY c.Id, c.CompanyName, o.orderid
HAVING amount >= 10000
ORDER BY amount DESC
"""

# WHERE YEAR(cast(o.orderdate as date)) = 1997 -- postgres has function YEAR.
# WHERE strftime('%y', o.orderdate) = '1997' -- this gives empty result.

# WHERE o.orderdate >= '19970101' and o.orderdate < '19980101' -- gives empty result.

pd.read_sql(q,conn)
# Out:
#   CustomerID                 CompanyName  orderid   amount
# 0      SIMOB               Simons bistro    10417  11188.4
# 1      RATTC  Rattlesnake Canyon Grocery    10479  10495.6
# 2      QUICK                  QUICK-Stop    10540  10191.7
# 3      QUICK                  QUICK-Stop    10691  10164.8

# %%
# pd.read_sql("pragma table_info('Orders')",conn)

# %%
tmp
# Out:
#    customerid                 CompanyName  OrderId  TotalOrderAmount
# 0       SIMOB               Simons bistro    10417           11188.4
# 4       RATTC  Rattlesnake Canyon Grocery    10479           10495.6
# 8       QUICK                  QUICK-Stop    10540           10191.7
# 12      QUICK                  QUICK-Stop    10691           10164.8

# %%
spark.sql(q).show()
# Out:
# +----------+--------------------+-------+-------+
# |CustomerID|         CompanyName|OrderID| amount|
# +----------+--------------------+-------+-------+
# |     SIMOB|       Simons bistro|  10417|11188.4|
# |     RATTC|Rattlesnake Canyo...|  10479|10495.6|
# |     QUICK|          QUICK-Stop|  10540|10191.7|
# |     QUICK|          QUICK-Stop|  10691|10164.8|
# +----------+--------------------+-------+-------+

# %% [markdown]
# ## 33. High-value customers - total orders
# ```
# The manager has changed his mind. Instead of
# requiring that customers have at least one individual
# orders totaling 10,000 or more, he wants to define
# high-value customers as those who have orders
# totaling 15,000 or more in 1997. How would you
# change the answer to the problem above?
# ```

# %%
Orders.head(1)
# Out:
#    orderid customerid  employeeid  orderdate requireddate shippeddate  \
# 0    10248      VINET           5 1996-07-04   1996-08-01  1996-07-16
#
#    shipvia    freight                   shipname         shipaddress shipcity  \
# 0        3  32.380001  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
#
#   shipregion shippostalcode shipcountry
# 0       None          51100      France

# %%
OrderDetails.head(1)
# Out:
#          Id  OrderId  ProductId  UnitPrice  Quantity  Discount
# 0  10248/11    10248         11       14.0        12       0.0

# %%
Customers.head(1)
# Out:
#       Id          CompanyName   ContactName          ContactTitle  \
# 0  ALFKI  Alfreds Futterkiste  Maria Anders  Sales Representative
#
#          Address    City Region PostalCode  Country        Phone          Fax
# 0  Obere Str. 57  Berlin   None      12209  Germany  030-0074321  030-0076545

# %%
df = Orders.merge(OrderDetails,
                  left_on='orderid',right_on='OrderId',
                  suffixes=['_o','_od'])\
           .merge(Customers,
                 left_on='customerid',right_on='Id',
                 suffixes=['_o_od','_c'])\
           .loc[lambda dfx: dfx['orderdate'].dt.year==1997]\
           .assign(OrderAmount = 
                   lambda dfx: (  dfx['UnitPrice'] 
                                * dfx['Quantity']
                                *(1- dfx['Discount'])
                               ))\
           .assign(CustomerSum = 
                  lambda dfx: dfx.groupby(['customerid','CompanyName'])
                                  ['OrderAmount'].transform('sum') 
                  )\
           .loc[lambda dfx: dfx['CustomerSum']>15000]\
           .drop_duplicates(['customerid','CompanyName'])\
           .sort_values('CustomerSum',ascending=False)\
           .reset_index(drop=True)\
           [['customerid','CompanyName','CustomerSum']]


print(df.shape)
df
# Out:
# (7, 3)
#   customerid                   CompanyName  CustomerSum
# 0      QUICK                    QUICK-Stop   61109.9100
# 1      SAVEA            Save-a-lot Markets   57713.5750
# 2      ERNSH                  Ernst Handel   48096.2635
# 3      MEREP                Mère Paillarde   23332.3100
# 4      HUNGO  Hungry Owl All-Night Grocers   20454.4050
# 5      RATTC    Rattlesnake Canyon Grocery   19383.7500
# 6      SIMOB                 Simons bistro   16232.4125

# %%
q = """
SELECT c.Id as CustomerID,
  c.CompanyName,
  sum( od.UnitPrice * od.Quantity * (1-od.Discount)) AS CustomerSum

FROM Customers AS c
  INNER JOIN Orders AS o
    ON c.Id = o.customerid
  INNER JOIN OrderDetails AS od
    ON o.orderid = od.OrderId

WHERE substr(o.orderdate,1,4) = '1997'

GROUP BY c.Id, c.CompanyName
HAVING CustomerSum >= 15000
ORDER BY CustomerSum DESC
"""

pd.read_sql(q,conn)
# Out:
#   CustomerID                   CompanyName  CustomerSum
# 0      QUICK                    QUICK-Stop   61109.9100
# 1      SAVEA            Save-a-lot Markets   57713.5750
# 2      ERNSH                  Ernst Handel   48096.2635
# 3      MEREP                Mère Paillarde   23332.3100
# 4      HUNGO  Hungry Owl All-Night Grocers   20454.4050
# 5      RATTC    Rattlesnake Canyon Grocery   19383.7500
# 6      SIMOB                 Simons bistro   16232.4125

# %%
df
# Out:
#   customerid                   CompanyName  CustomerSum
# 0      QUICK                    QUICK-Stop   61109.9100
# 1      SAVEA            Save-a-lot Markets   57713.5750
# 2      ERNSH                  Ernst Handel   48096.2635
# 3      MEREP                Mère Paillarde   23332.3100
# 4      HUNGO  Hungry Owl All-Night Grocers   20454.4050
# 5      RATTC    Rattlesnake Canyon Grocery   19383.7500
# 6      SIMOB                 Simons bistro   16232.4125

# %%
spark.sql(q).show()
# Out:
# +----------+--------------------+------------------+
# |CustomerID|         CompanyName|       CustomerSum|
# +----------+--------------------+------------------+
# |     QUICK|          QUICK-Stop|          61109.91|
# |     SAVEA|  Save-a-lot Markets|57713.575000000004|
# |     ERNSH|        Ernst Handel|        48096.2635|
# |     MEREP|      Mère Paillarde|          23332.31|
# |     HUNGO|Hungry Owl All-Ni...|         20454.405|
# |     RATTC|Rattlesnake Canyo...|          19383.75|
# |     SIMOB|       Simons bistro|16232.412499999999|
# +----------+--------------------+------------------+

# %% [markdown]
# ## 34. High-value customers - with discount
# Change the above query to use the discount when
# calculating high-value customers. Order by the total
# amount which includes the discount.

# %%
# I already included discount.

# %% [markdown]
# ## 35. Month-end orders
# At the end of the month, salespeople are likely to try
# much harder to get orders, to meet their month-end
# quotas. Show all orders made on the last day of the
# month. Order by EmployeeID and OrderID
#
# - https://www.sqlitetutorial.net/sqlite-date-functions/sqlite-date-function/

# %%
# we need EmployeeID OrderID OrderDate
# Only Orders table is needed.

# %%
Orders.head(1)
# Out:
#    orderid customerid  employeeid  orderdate requireddate shippeddate  \
# 0    10248      VINET           5 1996-07-04   1996-08-01  1996-07-16
#
#    shipvia    freight                   shipname         shipaddress shipcity  \
# 0        3  32.380001  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
#
#   shipregion shippostalcode shipcountry
# 0       None          51100      France

# %%
Orders.groupby([Orders.orderdate.dt.year,Orders.orderdate.dt.month],as_index=False).orderdate.transform('max').head()
# Out:
#    orderdate
# 0 1996-07-31
# 1 1996-07-31
# 2 1996-07-31
# 3 1996-07-31
# 4 1996-07-31

# %%
Orders.groupby([Orders.orderdate.dt.year,Orders.orderdate.dt.month],as_index=False).orderdate.transform('max').tail()
# Out:
#      orderdate
# 825 1998-05-06
# 826 1998-05-06
# 827 1998-05-06
# 828 1998-05-06
# 829 1998-05-06

# %%
(Orders[Orders.orderdate.dt.day
        == Orders.orderdate.dt.days_in_month]
  .sort_values(['employeeid','orderid'])
  [['employeeid','orderid','orderdate']]
  .reset_index(drop=True)
)
# Out:
#     employeeid  orderid  orderdate
# 0            1    10461 1997-02-28
# 1            1    10616 1997-07-31
# 2            2    10583 1997-06-30
# 3            2    10686 1997-09-30
# 4            2    10989 1998-03-31
# 5            2    11060 1998-04-30
# 6            3    10432 1997-01-31
# 7            3    10806 1997-12-31
# 8            3    10988 1998-03-31
# 9            3    11063 1998-04-30
# 10           4    10343 1996-10-31
# 11           4    10522 1997-04-30
# 12           4    10584 1997-06-30
# 13           4    10617 1997-07-31
# 14           4    10725 1997-10-31
# 15           4    10807 1997-12-31
# 16           4    11061 1998-04-30
# 17           4    11062 1998-04-30
# 18           5    10269 1996-07-31
# 19           6    10317 1996-09-30
# 20           7    10490 1997-03-31
# 21           8    10399 1996-12-31
# 22           8    10460 1997-02-28
# 23           8    10491 1997-03-31
# 24           8    10987 1998-03-31
# 25           9    10687 1997-09-30

# %%
q = """
SELECT EmployeeID, OrderID, OrderDate
FROM Orders
WHERE DAY(DATE_ADD(OrderDate, INTERVAL 1 DAY)) = 1
ORDER BY EmployeeID, OrderID
"""

# pd.read_sql(q,conn) # works for postgres

# %%
# https://www.sqlitetutorial.net/sqlite-date-functions/sqlite-date-function/
q = """
SELECT EmployeeID, OrderID, OrderDate
FROM Orders

WHERE orderdate = (select date(orderdate, 'start of month',
                             '+1 month', '-1 day'))

ORDER BY EmployeeID, OrderID

"""

pd.read_sql(q,conn) # sqlite
# Out:
#     employeeid  orderid   orderdate
# 0            1    10461  1997-02-28
# 1            1    10616  1997-07-31
# 2            2    10583  1997-06-30
# 3            2    10686  1997-09-30
# 4            2    10989  1998-03-31
# 5            2    11060  1998-04-30
# 6            3    10432  1997-01-31
# 7            3    10806  1997-12-31
# 8            3    10988  1998-03-31
# 9            3    11063  1998-04-30
# 10           4    10343  1996-10-31
# 11           4    10522  1997-04-30
# 12           4    10584  1997-06-30
# 13           4    10617  1997-07-31
# 14           4    10725  1997-10-31
# 15           4    10807  1997-12-31
# 16           4    11061  1998-04-30
# 17           4    11062  1998-04-30
# 18           5    10269  1996-07-31
# 19           6    10317  1996-09-30
# 20           7    10490  1997-03-31
# 21           8    10399  1996-12-31
# 22           8    10460  1997-02-28
# 23           8    10491  1997-03-31
# 24           8    10987  1998-03-31
# ...

# %%
q = """
SELECT EmployeeID, OrderID, OrderDate
FROM Orders
WHERE orderdate = last_day(orderdate)
ORDER BY EmployeeID, OrderID
"""

spark.sql(q).show()
# Out:
# +----------+-------+----------+
# |EmployeeID|OrderID| OrderDate|
# +----------+-------+----------+
# |         1|  10461|1997-02-28|
# |         1|  10616|1997-07-31|
# |         2|  10583|1997-06-30|
# |         2|  10686|1997-09-30|
# |         2|  10989|1998-03-31|
# |         2|  11060|1998-04-30|
# |         3|  10432|1997-01-31|
# |         3|  10806|1997-12-31|
# |         3|  10988|1998-03-31|
# |         3|  11063|1998-04-30|
# |         4|  10343|1996-10-31|
# |         4|  10522|1997-04-30|
# |         4|  10584|1997-06-30|
# |         4|  10617|1997-07-31|
# |         4|  10725|1997-10-31|
# |         4|  10807|1997-12-31|
# |         4|  11061|1998-04-30|
# |         4|  11062|1998-04-30|
# |         5|  10269|1996-07-31|
# |         6|  10317|1996-09-30|
# +----------+-------+----------+
# only showing top 20 rows

# %% [markdown]
# ## 36. Orders with many line items
# The Northwind mobile app developers are testing an
# app that customers will use to show orders. In order
# to make sure that even the largest orders will show
# up correctly on the app, they'd like some samples of
# orders that have lots of individual line items. Show
# the 10 orders with the most line items, in order of
# total line items.

# %%
Orders.head(1)
# Out:
#    orderid customerid  employeeid  orderdate requireddate shippeddate  \
# 0    10248      VINET           5 1996-07-04   1996-08-01  1996-07-16
#
#    shipvia    freight                   shipname         shipaddress shipcity  \
# 0        3  32.380001  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
#
#   shipregion shippostalcode shipcountry
# 0       None          51100      France

# %%
OrderDetails.head(1)
# Out:
#          Id  OrderId  ProductId  UnitPrice  Quantity  Discount
# 0  10248/11    10248         11       14.0        12       0.0

# %%
OrderDetails.groupby('OrderId')['Id'].count().nlargest(10)
# Out:
# OrderId
# 11077    25
# 10657     6
# 10847     6
# 10979     6
# 10273     5
# 10294     5
# 10309     5
# 10324     5
# 10325     5
# 10337     5
# Name: Id, dtype: int64

# %%
q = """select * from OrderDetails limit 1"""
pd.read_sql(q,conn)
# Out:
#          Id  OrderId  ProductId  UnitPrice  Quantity  Discount
# 0  10248/11    10248         11         14        12       0.0

# %%
q = """
select OrderId, count(*) as TotalOrderDetails
from OrderDetails
group by orderid
order by TotalOrderDetails desc
limit 10
"""

pd.read_sql(q,conn)
# Out:
#    OrderId  TotalOrderDetails
# 0    11077                 25
# 1    10657                  6
# 2    10847                  6
# 3    10979                  6
# 4    10273                  5
# 5    10294                  5
# 6    10309                  5
# 7    10324                  5
# 8    10325                  5
# 9    10337                  5

# %%
# spark.sql(q).show()

# %%
sOrderDetails.groupby('OrderId').agg({'Id':'count'}).orderBy('count(Id)',ascending=False).limit(10).show()
# Out:
# +-------+---------+
# |OrderId|count(Id)|
# +-------+---------+
# |  11077|       25|
# |  10979|        6|
# |  10847|        6|
# |  10657|        6|
# |  10514|        5|
# |  10294|        5|
# |  10962|        5|
# |  10558|        5|
# |  10845|        5|
# |  10458|        5|
# +-------+---------+

# %% [markdown]
# ## 37. Orders - random assortment
# The Northwind mobile app developers would now
# like to just get a random assortment of orders for beta
# testing on their app. Show a random set of 2% of all
# orders.

# %%
Orders.shape
# Out:
# (830, 14)

# %%
Orders.sample(frac=0.02,random_state=100).shape
# Out:
# (17, 14)

# %%
q = """
select * from Orders order by RANDOM() limit 2
"""

pd.read_sql(q,conn)
# Out:
#    orderid customerid  employeeid   orderdate requireddate shippeddate  \
# 0    10601      HILAA           7  1997-07-16   1997-08-27  1997-07-22
# 1    10350      LAMAI           6  1996-11-11   1996-12-09  1996-12-03
#
#    shipvia    freight          shipname  \
# 0        1  58.299999  HILARION-Abastos
# 1        2  64.190002  La maison d'Asie
#
#                                   shipaddress       shipcity shipregion  \
# 0  Carrera 22 con Ave. Carlos Soublette #8-35  San Cristóbal    Táchira
# 1                       1 rue Alsace-Lorraine       Toulouse       None
#
#   shippostalcode shipcountry
# 0           5022   Venezuela
# 1          31000      France

# %%
q = """
select cast(0.2 * count(*) as int) from Orders
"""

pd.read_sql(q,conn)
# Out:
#    cast(0.2 * count(*) as int)
# 0                          166

# %%
q = """
select * from Orders
order by RANDOM()
limit (
        select cast(0.2 * count(*) as int) from Orders
        )
"""

pd.read_sql(q,conn).shape
# Out:
# (166, 14)

# %%
# ms sql server
q_ms_sql = """
Select top 2 percent
OrderID
From Orders
Order By NewID()
""";

# %%
sOrders.sample(fraction=0.2).show(2)
# Out:
# +-------+----------+----------+----------+------------+-----------+-------+----------+--------------------+-------------------+--------+----------+--------------+-----------+
# |orderid|customerid|employeeid| orderdate|requireddate|shippeddate|shipvia|   freight|            shipname|        shipaddress|shipcity|shipregion|shippostalcode|shipcountry|
# +-------+----------+----------+----------+------------+-----------+-------+----------+--------------------+-------------------+--------+----------+--------------+-----------+
# |  10266|     WARTH|         3|1996-07-26|  1996-09-06| 1996-07-31|      3|25.7299995|      Wartian Herkku|        Torikatu 38|    Oulu|      null|         90110|    Finland|
# |  10269|     WHITC|         5|1996-07-31|  1996-08-14| 1996-08-09|      1|4.55999994|White Clover Markets|1029 - 12th Ave. S.| Seattle|        WA|         98124|        USA|
# ...

# %%
# spark.sql(q) # function RANDOM() is not in pyspark sql

# %%
q = """
select orderid, customerid from Orders tablesample(2 percent)
""";

spark.sql(q).show()
# Out:
# +-------+----------+
# |orderid|customerid|
# +-------+----------+
# |  10400|     EASTC|
# |  10426|     GALED|
# |  10442|     ERNSH|
# |  10581|     FAMIA|
# |  10643|     ALFKI|
# |  10701|     HUNGO|
# |  10712|     HUNGO|
# |  10836|     ERNSH|
# |  10843|     VICTE|
# |  10968|     ERNSH|
# +-------+----------+

# %% [markdown]
# ## 38. Orders - accidental double-entry
# Janet Leverling, one of the salespeople, has come to
# you with a request. She thinks that she accidentally
# double-entered a line item on an order, with a
# different ProductID, but the same quantity. She
# remembers that the quantity was 60 or more. Show
# all the OrderIDs with line items that match this, in
# order of OrderID.

# %%
OrderDetails.head(2)
# Out:
#          Id  OrderId  ProductId  UnitPrice  Quantity  Discount
# 0  10248/11    10248         11       14.0        12       0.0
# 1  10248/42    10248         42        9.8        10       0.0

# %%
idx = OrderDetails[OrderDetails.Quantity >= 60]\
        .groupby(['OrderId','Quantity'])['Id'].transform('count')\
        .loc[lambda x: x>1].index

# OrderDetails.loc[idx]

# %%
f = OrderDetails[OrderDetails.Quantity >= 60]\
    .groupby(['OrderId','Quantity'])['Id']\
    .filter(lambda dfx: len(dfx)>1)
       
# OrderDetails.loc[f.index]

# %%
OrderDetails[OrderDetails.Quantity >= 60]\
    .groupby(['OrderId','Quantity'])['Id']\
    .filter(lambda dfx: len(dfx)>1)\
    .pipe(lambda x: OrderDetails.loc[x.index])\
    .drop_duplicates(['OrderId','Quantity'])
# Out:
#             Id  OrderId  ProductId  UnitPrice  Quantity  Discount
# 43    10263/16    10263         16       13.9        60      0.25
# 1080  10658/40    10658         40       18.4        70      0.05
# 1916  10990/21    10990         21       10.0        65      0.00
# 2017   11030/2    11030          2       19.0       100      0.25

# %%
# sql

# %%
q = """
select * from OrderDetails
where Quantity >= 60
group by orderid,quantity
having count(*) > 1
order by orderid
"""
pd.read_sql(q,conn)
# Out:
#          Id  OrderId  ProductId  UnitPrice  Quantity  Discount
# 0  10263/16    10263         16       13.9        60      0.25
# 1  10658/40    10658         40       18.4        70      0.05
# 2  10990/21    10990         21       10.0        65      0.00
# 3   11030/2    11030          2       19.0       100      0.25

# %%
spark.sql('select * from OrderDetails limit 1').show()
# Out:
# +--------+-------+---------+---------+--------+--------+
# |      Id|OrderId|ProductId|UnitPrice|Quantity|Discount|
# +--------+-------+---------+---------+--------+--------+
# |10248/11|  10248|       11|     14.0|      12|     0.0|
# +--------+-------+---------+---------+--------+--------+

# %%
q = """
select OrderId, Quantity
-- CAVEAT: select * does not work.
from OrderDetails
where Quantity >= 60
group by OrderId, Quantity
having count(*) > 1
order by OrderId
"""

spark.sql(q).show()
# Out:
# +-------+--------+
# |OrderId|Quantity|
# +-------+--------+
# |  10263|      60|
# |  10658|      70|
# |  10990|      65|
# |  11030|     100|
# +-------+--------+

# %% [markdown]
# ## 39. Orders - accidental double-entry details
# Based on the previous question, we now want to
# show details of the order, for orders that match the
# above criteria.

# %%
OrderDetails.head(2)
# we want all orders from orderid such that this orderid matches above criteria.
# Out:
#          Id  OrderId  ProductId  UnitPrice  Quantity  Discount
# 0  10248/11    10248         11       14.0        12       0.0
# 1  10248/42    10248         42        9.8        10       0.0

# %%
dfx = OrderDetails[OrderDetails.Quantity >= 60]\
    .groupby(['OrderId','Quantity'])['Id']\
    .filter(lambda dfx: len(dfx)>1)


dfx.index
# Out:
# Int64Index([43, 45, 1080, 1082, 1916, 1918, 2017, 2020], dtype='int64')

# %%
OrderDetails.loc[f.index]['OrderId']
# Out:
# 43      10263
# 45      10263
# 1080    10658
# 1082    10658
# 1916    10990
# 1918    10990
# 2017    11030
# 2020    11030
# Name: OrderId, dtype: int64

# %%
OrderDetails[OrderDetails.Quantity >= 60]\
    .groupby(['OrderId','Quantity'])['Id']\
    .filter(lambda dfx: len(dfx)>1)\
    .pipe(lambda dfx: OrderDetails[
                        OrderDetails.OrderId.isin(
                          OrderDetails.loc[dfx.index]['OrderId'])
                                  ])\
    .reset_index(drop=True)
# Out:
#           Id  OrderId  ProductId  UnitPrice  Quantity  Discount
# 0   10263/16    10263         16      13.90        60      0.25
# 1   10263/24    10263         24       3.60        28      0.00
# 2   10263/30    10263         30      20.70        60      0.25
# 3   10263/74    10263         74       8.00        36      0.25
# 4   10658/21    10658         21      10.00        60      0.00
# 5   10658/40    10658         40      18.40        70      0.05
# 6   10658/60    10658         60      34.00        55      0.05
# 7   10658/77    10658         77      13.00        70      0.05
# 8   10990/21    10990         21      10.00        65      0.00
# 9   10990/34    10990         34      14.00        60      0.15
# 10  10990/55    10990         55      24.00        65      0.15
# 11  10990/61    10990         61      28.50        66      0.15
# 12   11030/2    11030          2      19.00       100      0.25
# 13   11030/5    11030          5      21.35        70      0.00
# ...

# %%
# using CTE and subquery
q = """
select *
from OrderDetails
where OrderID in (
    select distinct OrderID
    from OrderDetails
    where Quantity >= 60
    group by OrderID, Quantity
    having count(*) > 1
    order by OrderID
    )
order by Quantity
"""

# pd.read_sql(q,conn)

# %%
# spark.sql(q).show()

# %% [markdown]
# ## 40. Orders - accidental double-entry
# details, derived table
# Here's another way of getting the same results as in
# the previous problem, using a derived table instead of
# a CTE. However, there's a bug in this SQL. It returns
# 20 rows instead of 16. Correct the SQL.
# Problem SQL:
# ```sql
# Select
#   OrderDetails.OrderID,
#   ProductID,
#   UnitPrice,
#   Quantity,
#   Discount
# From OrderDetails
#   Join (
#     Select
#       OrderID
#       From OrderDetails
#       Where Quantity >= 60
#       Group By OrderID, Quantity
#       Having Count(*) > 1
#        ) PotentialProblemOrders
#   on PotentialProblemOrders.OrderID = OrderDetails.OrderID
# Order by OrderID, ProductID
# ```

# %%
pd.read_sql('select * from OrderDetails limit 1',conn)
# Out:
#          Id  OrderId  ProductId  UnitPrice  Quantity  Discount
# 0  10248/11    10248         11         14        12       0.0

# %%
q = """
Select
  od.OrderID,
  ProductID,
  UnitPrice,
  Quantity,
  Discount
From OrderDetails as od
  Join (
    Select
      OrderID
      From OrderDetails
      Where Quantity >= 60
      Group By OrderID, Quantity
      Having Count(*) > 1
       ) sub
  on sub.OrderID = od.OrderID
Order by od.OrderID, od.ProductID
"""

pd.read_sql(q,conn)
# Out:
#     OrderId  ProductId  UnitPrice  Quantity  Discount
# 0     10263         16      13.90        60      0.25
# 1     10263         24       3.60        28      0.00
# 2     10263         30      20.70        60      0.25
# 3     10263         74       8.00        36      0.25
# 4     10658         21      10.00        60      0.00
# 5     10658         40      18.40        70      0.05
# 6     10658         60      34.00        55      0.05
# 7     10658         77      13.00        70      0.05
# 8     10990         21      10.00        65      0.00
# 9     10990         34      14.00        60      0.15
# 10    10990         55      24.00        65      0.15
# 11    10990         61      28.50        66      0.15
# 12    11030          2      19.00       100      0.25
# 13    11030          5      21.35        70      0.00
# 14    11030         29     123.79        60      0.25
# 15    11030         59      55.00       100      0.25

# %%
# spark.sql(q).show()

# %% [markdown]
# ## 41. Late orders
# Some customers are complaining about their orders
# arriving late. Which orders are late?

# %%
Orders.head(1)
# Out:
#    orderid customerid  employeeid  orderdate requireddate shippeddate  \
# 0    10248      VINET           5 1996-07-04   1996-08-01  1996-07-16
#
#    shipvia    freight                   shipname         shipaddress shipcity  \
# 0        3  32.380001  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
#
#   shipregion shippostalcode shipcountry
# 0       None          51100      France

# %%
Orders[Orders.shippeddate > Orders.requireddate].head(2)
# Out:
#     orderid customerid  employeeid  orderdate requireddate shippeddate  \
# 16    10264      FOLKO           6 1996-07-24   1996-08-21  1996-08-23
# 23    10271      SPLIR           6 1996-08-01   1996-08-29  1996-08-30
#
#     shipvia  freight               shipname   shipaddress shipcity shipregion  \
# 16        3     3.67         Folk och fä HB  Åkergatan 24   Bräcke       None
# 23        2     4.54  Split Rail Beer & Ale  P.O. Box 555   Lander         WY
#
#    shippostalcode shipcountry
# 16       S-844 67      Sweden
# 23          82520         USA

# %%
# pd.read_sql('pragma table_info("Orders")',conn)

# %%
# we can see the pragma of date related columns are already datetype
# we dont need to cast them as date.

# %%
q = """
select *
from Orders
where shippeddate > requireddate
"""

# pd.read_sql(q,conn)

# %%
# spark.sql(q).show()

# %% [markdown]
# ## 42. Late orders - which employees?
# Some salespeople have more orders arriving late than
# others. Maybe they're not following up on the order
# process, and need more training. Which salespeople
# have the most orders arriving late?

# %%
Orders[Orders.shippeddate > Orders.requireddate].head(1)
# Out:
#     orderid customerid  employeeid  orderdate requireddate shippeddate  \
# 16    10264      FOLKO           6 1996-07-24   1996-08-21  1996-08-23
#
#     shipvia  freight        shipname   shipaddress shipcity shipregion  \
# 16        3     3.67  Folk och fä HB  Åkergatan 24   Bräcke       None
#
#    shippostalcode shipcountry
# 16       S-844 67      Sweden

# %%
Employees.head(1)
# Out:
#    Id LastName FirstName                 Title TitleOfCourtesy   BirthDate  \
# 0   1  Davolio     Nancy  Sales Representative             Ms.  1948-12-08
#
#      HireDate                     Address     City Region PostalCode Country  \
# 0  1992-05-01  507 - 20th Ave. E. Apt. 2A  Seattle     WA      98122     USA
#
#         HomePhone Extension Photo  \
# 0  (206) 555-9857      5467  None
#
#                                                Notes  ReportsTo  \
# 0  Education includes a BA in psychology from Col...        2.0
#
#                               PhotoPath
# 0  http://accweb/emmployees/davolio.bmp

# %%
Orders[Orders.shippeddate > Orders.requireddate]\
.groupby('employeeid')['orderid'].count().rename('TotalLateOrders')\
.sort_values(ascending=False).reset_index()\
.merge(Employees,left_on='employeeid',right_on='Id',suffixes=['_late','_emp'])\
[['employeeid','TotalLateOrders','FirstName','LastName']]
# Out:
#    employeeid  TotalLateOrders FirstName   LastName
# 0           4               10  Margaret    Peacock
# 1           3                5     Janet  Leverling
# 2           9                4      Anne  Dodsworth
# 3           8                4     Laura   Callahan
# 4           7                4    Robert       King
# 5           2                4    Andrew     Fuller
# 6           6                3   Michael     Suyama
# 7           1                2     Nancy    Davolio
# 8           5                1    Steven   Buchanan

# %%
pd.read_sql("select * from Orders limit 1",conn)
# Out:
#    orderid customerid  employeeid   orderdate requireddate shippeddate  \
# 0    10248      VINET           5  1996-07-04   1996-08-01  1996-07-16
#
#    shipvia    freight                   shipname         shipaddress shipcity  \
# 0        3  32.380001  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
#
#   shipregion shippostalcode shipcountry
# 0       None          51100      France

# %%
pd.read_sql("select * from Employees limit 1",conn)
# Out:
#    Id LastName FirstName                 Title TitleOfCourtesy   BirthDate  \
# 0   1  Davolio     Nancy  Sales Representative             Ms.  1948-12-08
#
#      HireDate                     Address     City Region PostalCode Country  \
# 0  1992-05-01  507 - 20th Ave. E. Apt. 2A  Seattle     WA      98122     USA
#
#         HomePhone Extension Photo  \
# 0  (206) 555-9857      5467  None
#
#                                                Notes  ReportsTo  \
# 0  Education includes a BA in psychology from Col...          2
#
#                               PhotoPath
# 0  http://accweb/emmployees/davolio.bmp

# %%
q = """
select e.Id, e.LastName,
       count(*) as TotalLateOrders
from Employees e
join Orders o
on o.employeeid = e.id
where o.shippeddate > o.requireddate
group by o.employeeid, e.LastName
order by count(*) desc
"""

pd.read_sql(q,conn)
# Out:
#    Id   LastName  TotalLateOrders
# 0   4    Peacock               10
# 1   3  Leverling                5
# 2   2     Fuller                4
# 3   7       King                4
# 4   8   Callahan                4
# 5   9  Dodsworth                4
# 6   6     Suyama                3
# 7   1    Davolio                2
# 8   5   Buchanan                1

# %%
# WARNING: cast as date gives WRONG result.
q = """
select e.Id, e.LastName,
       count(*) as TotalLateOrders
from Employees e
join Orders o
on o.employeeid = e.id
where cast(o.shippeddate as date) > cast(o.requireddate as date)
group by o.employeeid, e.LastName
order by count(*) desc
"""

pd.read_sql(q,conn)
# Out:
#    Id LastName  TotalLateOrders
# 0   7     King                1

# %%
q = """
select shippeddate, cast(o.shippeddate as date)
from Orders o
limit 2
"""

pd.read_sql(q,conn)
# Out:
#   shippeddate  cast(o.shippeddate as date)
# 0  1996-07-16                         1996
# 1  1996-07-10                         1996

# %% [markdown]
# ## 43. Late orders vs. total orders
# Andrew, the VP of sales, has been doing some more
# thinking some more about the problem of late orders.
# He realizes that just looking at the number of orders
# arriving late for each salesperson isn't a good idea. It
# needs to be compared against the total number of
# orders per salesperson. Return results like the
# following:
# ```
# Expected Result
# EmployeeID LastName AllOrders LateOrders
# ----------- -------------------- ----------- -----------
# 1 Davolio 123 3
# 2 Fuller 96 4
# 3 Leverling 127 5
# 4 Peacock 156 10
# 6 Suyama 67 3
# 7 King 72 4
# 8 Callahan 104 5
# 9 Dodsworth 43 5
# ```

# %%
Orders.head(1)
# Out:
#    orderid customerid  employeeid  orderdate requireddate shippeddate  \
# 0    10248      VINET           5 1996-07-04   1996-08-01  1996-07-16
#
#    shipvia    freight                   shipname         shipaddress shipcity  \
# 0        3  32.380001  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
#
#   shipregion shippostalcode shipcountry
# 0       None          51100      France

# %%
Orders[Orders.shippeddate > Orders.requireddate]\
  .groupby('employeeid')['orderid'].count()\
  .rename('LateOrders').reset_index()
# Out:
#    employeeid  LateOrders
# 0           1           2
# 1           2           4
# 2           3           5
# 3           4          10
# 4           5           1
# 5           6           3
# 6           7           4
# 7           8           4
# 8           9           4

# %%
Orders.employeeid.value_counts().rename('AllOrders')\
.rename_axis('employeeid').reset_index()
# Out:
#    employeeid  AllOrders
# 0           4        156
# 1           3        127
# 2           1        123
# 3           8        104
# 4           2         96
# 5           7         72
# 6           6         67
# 7           9         43
# 8           5         42

# %%
Orders[Orders.shippeddate >= Orders.requireddate]\
  .groupby('employeeid')['orderid'].count()\
  .rename('LateOrders').reset_index()\
  .merge(Orders.employeeid.value_counts().rename('AllOrders')
              .rename_axis('employeeid').reset_index(),
        on='employeeid',suffixes=['_ord','_emp']
)\
.merge(
Employees, left_on='employeeid', right_on='Id',suffixes=['_old','']
)[['employeeid','LastName','AllOrders','LateOrders']]

# note: use >= not >
# Out:
#    employeeid   LastName  AllOrders  LateOrders
# 0           1    Davolio        123           3
# 1           2     Fuller         96           4
# 2           3  Leverling        127           5
# 3           4    Peacock        156          10
# 4           5   Buchanan         42           1
# 5           6     Suyama         67           3
# 6           7       King         72           4
# 7           8   Callahan        104           5
# 8           9  Dodsworth         43           5

# %%
Employees.head(1)
# Out:
#    Id LastName FirstName                 Title TitleOfCourtesy   BirthDate  \
# 0   1  Davolio     Nancy  Sales Representative             Ms.  1948-12-08
#
#      HireDate                     Address     City Region PostalCode Country  \
# 0  1992-05-01  507 - 20th Ave. E. Apt. 2A  Seattle     WA      98122     USA
#
#         HomePhone Extension Photo  \
# 0  (206) 555-9857      5467  None
#
#                                                Notes  ReportsTo  \
# 0  Education includes a BA in psychology from Col...        2.0
#
#                               PhotoPath
# 0  http://accweb/emmployees/davolio.bmp

# %%
pd.read_sql("select * from Employees limit 1",conn)
# Out:
#    Id LastName FirstName                 Title TitleOfCourtesy   BirthDate  \
# 0   1  Davolio     Nancy  Sales Representative             Ms.  1948-12-08
#
#      HireDate                     Address     City Region PostalCode Country  \
# 0  1992-05-01  507 - 20th Ave. E. Apt. 2A  Seattle     WA      98122     USA
#
#         HomePhone Extension Photo  \
# 0  (206) 555-9857      5467  None
#
#                                                Notes  ReportsTo  \
# 0  Education includes a BA in psychology from Col...          2
#
#                               PhotoPath
# 0  http://accweb/emmployees/davolio.bmp

# %%
pd.read_sql("select * from Orders limit 1",conn)
# Out:
#    orderid customerid  employeeid   orderdate requireddate shippeddate  \
# 0    10248      VINET           5  1996-07-04   1996-08-01  1996-07-16
#
#    shipvia    freight                   shipname         shipaddress shipcity  \
# 0        3  32.380001  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
#
#   shipregion shippostalcode shipcountry
# 0       None          51100      France

# %%
q = """
select e.Id,
       e.LastName,
       count(*) as TotalOrders,
       late.TotalLateOrders
from Employees as e
join Orders as o on o.employeeid = e.Id
join (
  select o.EmployeeId, e.LastName, count(*) as TotalLateOrders
  from Employees as e
  join Orders as o
  on o.EmployeeID = e.ID
  where o.shippeddate  >= o.requireddate
  group by o.EmployeeId, e.LastName
  order by count(*) desc
) as late on e.Id = late.EmployeeID
group by e.Id, e.LastName
"""

pd.read_sql(q,conn)
# Out:
#    Id   LastName  TotalOrders  TotalLateOrders
# 0   1    Davolio          123                3
# 1   2     Fuller           96                4
# 2   3  Leverling          127                5
# 3   4    Peacock          156               10
# 4   5   Buchanan           42                1
# 5   6     Suyama           67                3
# 6   7       King           72                4
# 7   8   Callahan          104                5
# 8   9  Dodsworth           43                5

# %%
# I am getting different result for Davolio with employee id 1

# %%
Orders.head(1)
# Out:
#    orderid customerid  employeeid  orderdate requireddate shippeddate  \
# 0    10248      VINET           5 1996-07-04   1996-08-01  1996-07-16
#
#    shipvia    freight                   shipname         shipaddress shipcity  \
# 0        3  32.380001  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
#
#   shipregion shippostalcode shipcountry
# 0       None          51100      France

# %%
Orders[Orders.employeeid==1].shape
# Out:
# (123, 14)

# %%
Orders[Orders.employeeid==1].head(2)
# Out:
#     orderid customerid  employeeid  orderdate requireddate shippeddate  \
# 10    10258      ERNSH           1 1996-07-17   1996-08-14  1996-07-23
# 22    10270      WARTH           1 1996-08-01   1996-08-29  1996-08-02
#
#     shipvia     freight        shipname   shipaddress shipcity shipregion  \
# 10        1  140.509995    Ernst Handel  Kirchgasse 6     Graz       None
# 22        1  136.539993  Wartian Herkku   Torikatu 38     Oulu       None
#
#    shippostalcode shipcountry
# 10           8010     Austria
# 22          90110     Finland

# %%
Employees.head(1)
# Out:
#    Id LastName FirstName                 Title TitleOfCourtesy   BirthDate  \
# 0   1  Davolio     Nancy  Sales Representative             Ms.  1948-12-08
#
#      HireDate                     Address     City Region PostalCode Country  \
# 0  1992-05-01  507 - 20th Ave. E. Apt. 2A  Seattle     WA      98122     USA
#
#         HomePhone Extension Photo  \
# 0  (206) 555-9857      5467  None
#
#                                                Notes  ReportsTo  \
# 0  Education includes a BA in psychology from Col...        2.0
#
#                               PhotoPath
# 0  http://accweb/emmployees/davolio.bmp

# %%
Orders.query("employeeid==1 and shippeddate > requireddate")
# Out:
#      orderid customerid  employeeid  orderdate requireddate shippeddate  \
# 461    10709      GOURL           1 1997-10-17   1997-11-14  1997-11-20
# 579    10827      BONAP           1 1998-01-12   1998-01-26  1998-02-06
#
#      shipvia     freight             shipname           shipaddress  \
# 461        3  210.800003  Gourmet Lanchonetes       Av. Brasil, 442
# 579        2   63.540001             Bon app'  12, rue des Bouchers
#
#       shipcity shipregion shippostalcode shipcountry
# 461   Campinas         SP      04876-786      Brazil
# 579  Marseille       None          13008      France

# %%
# I can see employeeid 1 is Daviolio and She has TWO late shipping.
# If I use shippeddate >= requireddate, then our results match.

# %%
q = """
select e.Id,
       e.LastName,
       count(*) as TotalOrders,
       late.TotalLateOrders
from Employees as e
join Orders as o on o.employeeid = e.Id
join (
  select o.EmployeeId, e.LastName, count(*) as TotalLateOrders
  from Employees as e
  join Orders as o
  on o.EmployeeID = e.ID
  where o.shippeddate  >= o.requireddate
  group by o.EmployeeId, e.LastName
  order by count(*) desc
) as late on e.Id = late.EmployeeID
group by e.Id, e.LastName, late.TotalLateOrders
"""

spark.sql(q).show()

error = """
If I do not include late.TotalLateOrders in group by I get following error:


expression 'late.`TotalLateOrders`' is neither present in the group by, nor is it an aggregate function. Add to group by or wrap in first() (or first_value) if you don't care which value you get.

""";
# Out:
# +---+---------+-----------+---------------+
# | Id| LastName|TotalOrders|TotalLateOrders|
# +---+---------+-----------+---------------+
# |  1|  Davolio|        123|              3|
# |  6|   Suyama|         67|              3|
# |  3|Leverling|        127|              5|
# |  5| Buchanan|         42|              1|
# |  9|Dodsworth|         43|              5|
# |  4|  Peacock|        156|             10|
# |  8| Callahan|        104|              5|
# |  7|     King|         72|              4|
# |  2|   Fuller|         96|              4|
# +---+---------+-----------+---------------+

# %% [markdown]
# ## 45. Late orders vs. total orders - fix null
# Continuing on the answer for above query, let's fix
# the results for row 5 - Buchanan. He should have a 0
# instead of a Null in LateOrders.

# %%
pd.read_sql("select * from Employees limit 1",conn)
# Out:
#    Id LastName FirstName                 Title TitleOfCourtesy   BirthDate  \
# 0   1  Davolio     Nancy  Sales Representative             Ms.  1948-12-08
#
#      HireDate                     Address     City Region PostalCode Country  \
# 0  1992-05-01  507 - 20th Ave. E. Apt. 2A  Seattle     WA      98122     USA
#
#         HomePhone Extension Photo  \
# 0  (206) 555-9857      5467  None
#
#                                                Notes  ReportsTo  \
# 0  Education includes a BA in psychology from Col...          2
#
#                               PhotoPath
# 0  http://accweb/emmployees/davolio.bmp

# %%
pd.read_sql("select * from Orders limit 1",conn)
# Out:
#    orderid customerid  employeeid   orderdate requireddate shippeddate  \
# 0    10248      VINET           5  1996-07-04   1996-08-01  1996-07-16
#
#    shipvia    freight                   shipname         shipaddress shipcity  \
# 0        3  32.380001  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
#
#   shipregion shippostalcode shipcountry
# 0       None          51100      France

# %%
q = """
select e.Id,
       e.LastName,
       count(*) as TotalOrders,
       case when late.TotalLateOrders is null then 0
                 else late.TotalLateOrders end
       as TotalLateOrders
from Employees as e
join Orders as o on o.EmployeeID = e.Id
left join (
    select o.EmployeeID, e.LastName, count(*) as TotalLateOrders
    from Employees as e
    join Orders as o on o.EmployeeID = e.Id
    where o.ShippedDate  >= o.RequiredDate
    group by o.EmployeeID, e.LastName
    order by count(*) desc
) as late ON e.Id = late.EmployeeID
group by e.Id, e.LastName;
"""

pd.read_sql(q,conn)
# Out:
#    Id   LastName  TotalOrders  TotalLateOrders
# 0   1    Davolio          123                3
# 1   2     Fuller           96                4
# 2   3  Leverling          127                5
# 3   4    Peacock          156               10
# 4   5   Buchanan           42                1
# 5   6     Suyama           67                3
# 6   7       King           72                4
# 7   8   Callahan          104                5
# 8   9  Dodsworth           43                5

# %% [markdown]
# ## 46. Late orders vs. total orders - percentage
# Now we want to get the percentage of late orders
# over total orders.

# %%
Orders[Orders.shippeddate >= Orders.requireddate]\
  .groupby('employeeid')['orderid'].count()\
  .rename('LateOrders').reset_index()\
  .merge(Orders.employeeid.value_counts().rename('AllOrders')
              .rename_axis('employeeid').reset_index(),
        on='employeeid',suffixes=['_ord','_emp']
)\
.merge(
Employees, left_on='employeeid', right_on='Id',suffixes=['_old','']
)[['employeeid','LastName','AllOrders','LateOrders']]\
.assign(
PercentLateOrders = lambda dfx: (dfx['LateOrders']/dfx['AllOrders']))
# Out:
#    employeeid   LastName  AllOrders  LateOrders  PercentLateOrders
# 0           1    Davolio        123           3           0.024390
# 1           2     Fuller         96           4           0.041667
# 2           3  Leverling        127           5           0.039370
# 3           4    Peacock        156          10           0.064103
# 4           5   Buchanan         42           1           0.023810
# 5           6     Suyama         67           3           0.044776
# 6           7       King         72           4           0.055556
# 7           8   Callahan        104           5           0.048077
# 8           9  Dodsworth         43           5           0.116279

# %%
q = """
select e.Id,
       e.LastName,
       count(*) as TotalOrders,
       
       -- late.TotalLateOrders,
       -- Handle the missing values
       
       case when late.TotalLateOrders is null then 0
            else late.TotalLateOrders end 
            as TotalLateOrders,
       
       -- cast(late.TotalLateOrders as double) / cast(count(*) as double) as PercentLateOrders
       -- Handle missing values
       
       cast(
            case when late.TotalLateOrders is null then 0
            else late.TotalLateOrders end 
            as double
            ) 
       / cast(count(*) as double) 
       as PercentLateOrders
       

       
from Employees as e
join Orders as o on o.employeeid = e.Id
join (
  select o.EmployeeId, e.LastName, count(*) as TotalLateOrders
  from Employees as e
  join Orders as o
  on o.EmployeeID = e.ID
  where o.shippeddate  >= o.requireddate
  group by o.EmployeeId, e.LastName
  order by count(*) desc
) as late on e.Id = late.EmployeeID
group by e.Id, e.LastName
"""

pd.read_sql(q,conn)
# Out:
#    Id   LastName  TotalOrders  TotalLateOrders  PercentLateOrders
# 0   1    Davolio          123                3           0.024390
# 1   2     Fuller           96                4           0.041667
# 2   3  Leverling          127                5           0.039370
# 3   4    Peacock          156               10           0.064103
# 4   5   Buchanan           42                1           0.023810
# 5   6     Suyama           67                3           0.044776
# 6   7       King           72                4           0.055556
# 7   8   Callahan          104                5           0.048077
# 8   9  Dodsworth           43                5           0.116279

# %%
q = """
select e.Id,
       e.LastName,
       count(*) as TotalOrders,
       
       -- late.TotalLateOrders,
       -- Handle the missing values
       
       case when late.TotalLateOrders is null then 0
            else late.TotalLateOrders end 
            as TotalLateOrders,
       
       -- cast(late.TotalLateOrders as double) / cast(count(*) as double) as PercentLateOrders
       -- Handle missing values
       
       cast(
            case when late.TotalLateOrders is null then 0
            else late.TotalLateOrders end 
            as double
            ) 
       / cast(count(*) as double) 
       as PercentLateOrders

from Employees as e
join Orders as o on o.employeeid = e.Id
join (
  select o.EmployeeId, e.LastName, count(*) as TotalLateOrders
  from Employees as e
  join Orders as o
  on o.EmployeeID = e.ID
  where o.shippeddate  >= o.requireddate
  group by o.EmployeeId, e.LastName
  order by count(*) desc
) as late on e.Id = late.EmployeeID
group by e.Id, e.LastName, TotalLateOrders
"""

spark.sql(q).show()
# Out:
# +---+---------+-----------+---------------+--------------------+
# | Id| LastName|TotalOrders|TotalLateOrders|   PercentLateOrders|
# +---+---------+-----------+---------------+--------------------+
# |  1|  Davolio|        123|              3|0.024390243902439025|
# |  6|   Suyama|         67|              3| 0.04477611940298507|
# |  3|Leverling|        127|              5| 0.03937007874015748|
# |  5| Buchanan|         42|              1|0.023809523809523808|
# |  9|Dodsworth|         43|              5| 0.11627906976744186|
# |  4|  Peacock|        156|             10|  0.0641025641025641|
# |  8| Callahan|        104|              5| 0.04807692307692308|
# |  7|     King|         72|              4| 0.05555555555555555|
# |  2|   Fuller|         96|              4|0.041666666666666664|
# +---+---------+-----------+---------------+--------------------+

# %% [markdown]
# ## 47. Late orders vs. total orders - fix decimal
# So now for the PercentageLateOrders, we get a
# decimal value like we should. But to make the output
# easier to read, let's cut the PercentLateOrders off at 2
# digits to the right of the decimal point.

# %%
q = """
select e.Id,
       e.LastName,
       count(*) as TotalOrders,
       
       -- late.TotalLateOrders,
       -- Handle the missing values
       
       case when late.TotalLateOrders is null then 0
            else late.TotalLateOrders end 
            as TotalLateOrders,
       
       -- cast(late.TotalLateOrders as double) / cast(count(*) as double) as PercentLateOrders
       -- Handle missing values
       
       round(cast(
            case when late.TotalLateOrders is null then 0
            else late.TotalLateOrders end 
            as double
            ) 
       / cast(count(*) as double), 2)
       as PercentLateOrders

from Employees as e
join Orders as o on o.employeeid = e.Id
join (
  select o.EmployeeId, e.LastName, count(*) as TotalLateOrders
  from Employees as e
  join Orders as o
  on o.EmployeeID = e.ID
  where o.shippeddate  >= o.requireddate
  group by o.EmployeeId, e.LastName
  order by count(*) desc
) as late on e.Id = late.EmployeeID
group by e.Id, e.LastName, TotalLateOrders
"""

spark.sql(q).show()
# Out:
# +---+---------+-----------+---------------+-----------------+
# | Id| LastName|TotalOrders|TotalLateOrders|PercentLateOrders|
# +---+---------+-----------+---------------+-----------------+
# |  1|  Davolio|        123|              3|             0.02|
# |  6|   Suyama|         67|              3|             0.04|
# |  3|Leverling|        127|              5|             0.04|
# |  5| Buchanan|         42|              1|             0.02|
# |  9|Dodsworth|         43|              5|             0.12|
# |  4|  Peacock|        156|             10|             0.06|
# |  8| Callahan|        104|              5|             0.05|
# |  7|     King|         72|              4|             0.06|
# |  2|   Fuller|         96|              4|             0.04|
# +---+---------+-----------+---------------+-----------------+

# %% [markdown]
# ## 48. Customer grouping
# Andrew Fuller, the VP of sales at Northwind, would
# like to do a sales campaign for existing customers.
# He'd like to categorize customers into groups, based
# on how much they ordered in 1997. Then, depending
# on which group the customer is in, he will target the
# customer with different sales materials.
# The customer grouping categories are 0 to 1,000,
# 1,000 to 5,000, 5,000 to 10,000, and over 10,000.
# A good starting point for this query is the answer
# from the problem “High-value customers - total
# orders. We don’t want to show customers who don’t
# have any orders in 1997.
# Order the results by CustomerID.

# %%
# OrderDetails Orders Employees
# Data only for 1997, at least one order
# make categories
# order by customerid

# CustomerID CompanyName TotalOrderAmount CustomerGroup
# Orders     Customers   OrderDetails**   CreateThis

# %%
OrderDetails.head(1)
# Out:
#          Id  OrderId  ProductId  UnitPrice  Quantity  Discount
# 0  10248/11    10248         11       14.0        12       0.0

# %%
Orders.head(1)
# Out:
#    orderid customerid  employeeid  orderdate requireddate shippeddate  \
# 0    10248      VINET           5 1996-07-04   1996-08-01  1996-07-16
#
#    shipvia    freight                   shipname         shipaddress shipcity  \
# 0        3  32.380001  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
#
#   shipregion shippostalcode shipcountry
# 0       None          51100      France

# %%
Customers.head(1)
# Out:
#       Id          CompanyName   ContactName          ContactTitle  \
# 0  ALFKI  Alfreds Futterkiste  Maria Anders  Sales Representative
#
#          Address    City Region PostalCode  Country        Phone          Fax
# 0  Obere Str. 57  Berlin   None      12209  Germany  030-0074321  030-0076545

# %%
( OrderDetails.drop(['Id','ProductId'],axis=1)
 
 # create new column
 .assign(OrderPrice = lambda x: x['UnitPrice'] * x['Quantity'] * (1-x['Discount']))
 
 # drop unwanted columns
 .drop(['UnitPrice', 'Quantity', 'Discount'],axis=1)
 
 # merge with Orders only in 1997
 .merge(
    Orders[['orderid','customerid','orderdate']
          ].loc[lambda x: x.orderdate.dt.year==1997],
     left_on='OrderId',right_on='orderid',suffixes=['_od','']
       )
 
 # drop unwanted columns
 .drop(['OrderId','orderid','orderdate'],axis=1)
 
 # merge with Customers
 .merge(
     Customers[['Id','CompanyName']],
     left_on='customerid',right_on='Id',suffixes=['_old','']
 
 )
 
 # drop duplicate column Id
 .drop(['Id'],axis=1)
 
 # find sum of orders for given customer
 .assign(
     TotalOrderAmount = lambda dfx: 
        dfx.groupby('customerid')['OrderPrice'].transform('sum')
        )
 
 # drop unwanted column
 .drop('OrderPrice',1)
 
 # assign cut labels
 .assign(
     CustomerGroup = lambda dfx: pd.cut(dfx['TotalOrderAmount'],
                     bins=[0,1000,5000, 10000, np.inf],
                     labels=['Low','Medium','High','VeryHigh']
                    )
 
 )
 
 # drop duplicates
 .drop_duplicates('customerid')
 
 # order by customerid
 .sort_values('customerid')

 # reset
 .reset_index(drop=True)

).pipe(lambda x: [print(x.shape), display(x.head())])
# Out:
# (86, 4)
#   customerid                         CompanyName  TotalOrderAmount  \
# 0      ALFKI                 Alfreds Futterkiste         2022.5000
# 1      ANATR  Ana Trujillo Emparedados y helados          799.7500
# 2      ANTON             Antonio Moreno Taquería         5960.7775
# 3      AROUT                     Around the Horn         6406.9000
# 4      BERGS                  Berglunds snabbköp        13849.0150
#
#   CustomerGroup
# 0        Medium
# 1           Low
# 2          High
# 3          High
# 4      VeryHigh
# [None, None]

# %%
pd.read_sql("select * from Customers limit 1",conn)
# Out:
#       Id          CompanyName   ContactName          ContactTitle  \
# 0  ALFKI  Alfreds Futterkiste  Maria Anders  Sales Representative
#
#          Address    City Region PostalCode  Country        Phone          Fax
# 0  Obere Str. 57  Berlin   None      12209  Germany  030-0074321  030-0076545

# %%
q = """
select *,
       case
           when TotalOrder between 0    and 1000  then 'low'
           when TotalOrder between 1000 and 5000  then 'medium'
           when TotalOrder between 5000 and 10000 then 'high'
           when TotalOrder >= 10000               then 'very high' 
       end as CustomerGroup
from (
    select o.customerid,
           c.companyname,
           sum(od.unitprice * od.quantity) as TotalOrder
    from Orders as o
    join OrderDetails as od on o.orderid = od.orderid
    join Customers as c on o.customerid = c.id
    where substr(o.orderdate,1,4) = '1997'
    group by o.customerid, c.companyname
    order by o.customerid, c.companyname
)
"""

pd.read_sql(q,conn).pipe(lambda x: [print(x.shape), display(x.head())])
# Out:
# (86, 4)
#   customerid                         companyname  TotalOrder CustomerGroup
# 0      ALFKI                 Alfreds Futterkiste     2294.00        medium
# 1      ANATR  Ana Trujillo Emparedados y helados      799.75           low
# 2      ANTON             Antonio Moreno Taquería     6452.15          high
# 3      AROUT                     Around the Horn     6589.00          high
# 4      BERGS                  Berglunds snabbköp    14533.20     very high
# [None, None]

# %%
spark.sql(q).show(3)
# Out:
# +----------+--------------------+----------+-------------+
# |customerid|         companyname|TotalOrder|CustomerGroup|
# +----------+--------------------+----------+-------------+
# |     ALFKI| Alfreds Futterkiste|    2294.0|       medium|
# |     ANATR|Ana Trujillo Empa...|    799.75|          low|
# |     ANTON|Antonio Moreno Ta...|   6452.15|         high|
# +----------+--------------------+----------+-------------+
# only showing top 3 rows

# %% [markdown]
# ## 49. Customer grouping - fix null
# There's a bug with the answer for the previous
# question. The CustomerGroup value for one of the
# rows is null.
# Fix the SQL so that there are no nulls in the
# CustomerGroup field.

# %%
# in pandas, nulls are automatically ignored.

# %%
# the book says using BETWEEN works good for integers, but 
# for floats we should use >= and <

# %%
q = """
select *,
       case
           when TotalOrder >=0 and TotalOrder<1000  then 'low'
           when TotalOrder >=1000 and TotalOrder<5000  then 'medium'
           when TotalOrder >= 5000 and TotalOrder<10000 then 'high'
           when TotalOrder >= 10000 then 'very high'
       end as CustomerGroup
from (
    select o.customerid,
           c.companyname,
           sum(od.unitprice * od.quantity) as TotalOrder
    from Orders as o
    join OrderDetails as od on o.orderid = od.orderid
    join Customers as c on o.customerid = c.id
    where substr(o.orderdate,1,4) = '1997'
    group by o.customerid, c.companyname
    order by o.customerid, c.companyname
)
"""

pd.read_sql(q,conn).pipe(lambda x: [print(x.shape), display(x.head())])
# Out:
# (86, 4)
#   customerid                         companyname  TotalOrder CustomerGroup
# 0      ALFKI                 Alfreds Futterkiste     2294.00        medium
# 1      ANATR  Ana Trujillo Emparedados y helados      799.75           low
# 2      ANTON             Antonio Moreno Taquería     6452.15          high
# 3      AROUT                     Around the Horn     6589.00          high
# 4      BERGS                  Berglunds snabbköp    14533.20     very high
# [None, None]

# %% [markdown]
# ## 50. Customer grouping with percentage
# Based on the above query, show all the defined
# CustomerGroups, and the percentage in each. Sort by
# the total in each group, in descending order.

# %%
( OrderDetails.drop(['Id','ProductId'],axis=1)
 
 # create new column
 .assign(OrderPrice = lambda x: x['UnitPrice'] * x['Quantity'] * (1-x['Discount']))
 
 # drop unwanted columns
 .drop(['UnitPrice', 'Quantity', 'Discount'],axis=1)
 
 # merge with Orders only in 1997
 .merge(
    Orders[['orderid','customerid','orderdate']
          ].loc[lambda x: x.orderdate.dt.year==1997],
     left_on='OrderId',right_on='orderid',suffixes=['_od','']
       )
 
 # drop unwanted columns
 .drop(['OrderId','orderid','orderdate'],axis=1)
 
 # merge with Customers
 .merge(
     Customers[['Id','CompanyName']],
     left_on='customerid',right_on='Id',suffixes=['_old','']
 
 )
 
 # drop duplicate column Id
 .drop(['Id'],axis=1)
 
 # find sum of orders for given customer
 .assign(
     TotalOrderAmount = lambda dfx: 
        dfx.groupby('customerid')['OrderPrice'].transform('sum')
        )
 
 # drop unwanted column
 .drop('OrderPrice',1)
 
 # assign cut labels
 .assign(
     CustomerGroup = lambda dfx: pd.cut(dfx['TotalOrderAmount'],
                     bins=[0,1000,5000, 10000, np.inf],
                     labels=['Low','Medium','High','VeryHigh']
                    )
 
 )
 
 # drop duplicates
 .drop_duplicates('customerid')
 
 # order by customerid
 .sort_values('customerid')

 # reset
 .reset_index(drop=True)
 
 # groupby customergroup
 .groupby('CustomerGroup').agg(
     TotalInGroup = ('TotalOrderAmount','size'),
     #TotalOrderGroup = ('TotalOrderAmount','sum'),
     
     # this does not work, since it does not give aggregated 
     # result. therefore, we need to create percentage later.
     # A = ('TotalOrderAmount', lambda dfx: dfx/dfx.sum())
     # for one group of dfx, we need one sum value.
 )
 
 # create percentage separately
 .assign(
 PercentageInGroup = lambda dfx: dfx['TotalInGroup']
                                /dfx['TotalInGroup'].sum())
 
 # sort
 .sort_values('TotalInGroup',ascending=False)

)
# Out:
#                TotalInGroup  PercentageInGroup
# CustomerGroup
# Medium                   30           0.348837
# High                     23           0.267442
# VeryHigh                 17           0.197674
# Low                      16           0.186047

# %%
q = """


            SELECT
            o.customerid,
            coalesce(sum(od.unitprice * od.quantity),0) as total
      
            FROM
                Orders o
                INNER JOIN
                OrderDetails od
                on o.orderid = od.orderid
                WHERE substr(o.orderdate,1,4) = '1997'
                GROUP BY
                o.customerid



"""

# pd.read_sql(q,conn)

# %%
q = """

        select *,
           case 
           when o7.total >=0 and o7.total <1000  then 'low'
           when o7.total >=1000 and o7.total <5000  then 'medium'
           when o7.total >= 5000 and o7.total <10000 then 'high'
           when o7.total >= 10000 then 'very high'
           end as mygroup
        

        FROM
        (
            SELECT
            o.customerid,
            coalesce(sum(od.unitprice * od.quantity),0) as total
      
            FROM
                Orders o
                INNER JOIN
                OrderDetails od
                on o.orderid = od.orderid
                WHERE substr(o.orderdate,1,4) = '1997'
                GROUP BY
                o.customerid
        ) as o7
        


"""

pd.read_sql(q,conn).head()
# Out:
#   customerid     total    mygroup
# 0      ALFKI   2294.00     medium
# 1      ANATR    799.75        low
# 2      ANTON   6452.15       high
# 3      AROUT   6589.00       high
# 4      BERGS  14533.20  very high

# %%
q = """
SELECT  gc.mygroup, gc.group_total
        -- sum(gc.group_total) -- do this once to see the total
        ,(gc.group_total / 86.0 ) as percentage
        
        -- this gives only one row
        -- ,gc.group_total/ (select sum(gc.group_total))

        
FROM
(


    SELECT  cg.mygroup, count(cg.mygroup) as group_total
    FROM
    (

        select *,
           case 
           when o7.total >=0 and o7.total <1000  then 'low'
           when o7.total >=1000 and o7.total <5000  then 'medium'
           when o7.total >= 5000 and o7.total <10000 then 'high'
           when o7.total >= 10000 then 'very high'
           end as mygroup
        

        FROM
        (
            SELECT
            o.customerid,
            coalesce(sum(od.unitprice * od.quantity),0) as total
      
            FROM
                Orders o
                INNER JOIN
                OrderDetails od
                on o.orderid = od.orderid
                WHERE substr(o.orderdate,1,4) = '1997'
                GROUP BY
                o.customerid
        ) as o7
        
    ) as cg
    GROUP BY cg.mygroup
    
) as gc
ORDER BY gc.group_total DESC

"""

pd.read_sql(q,conn)
# Out:
#      mygroup  group_total  percentage
# 0     medium           29    0.337209
# 1       high           23    0.267442
# 2  very high           18    0.209302
# 3        low           16    0.186047

# %% [markdown]
# ## 51. Customer grouping - flexible

# %%
# I dont have extra table needed to solve this qn.

# %% [markdown]
# ## 52. Countries with suppliers or customers
# Some Northwind employees are planning a business
# trip, and would like to visit as many suppliers and
# customers as possible. For their planning, they’d like
# to see a list of all countries where suppliers and/or
# customers are based.

# %%
Suppliers.head(1)
# Out:
#    Id     CompanyName       ContactName        ContactTitle         Address  \
# 0   1  Exotic Liquids  Charlotte Cooper  Purchasing Manager  49 Gilbert St.
#
#      City Region PostalCode Country           Phone   Fax HomePage
# 0  London   None    EC1 4SD      UK  (171) 555-2222  None     None

# %%
Customers.head(1)
# Out:
#       Id          CompanyName   ContactName          ContactTitle  \
# 0  ALFKI  Alfreds Futterkiste  Maria Anders  Sales Representative
#
#          Address    City Region PostalCode  Country        Phone          Fax
# 0  Obere Str. 57  Berlin   None      12209  Germany  030-0074321  030-0076545

# %%
np.union1d(Suppliers['Country'],
           Customers['Country'])
# Out:
# array(['Argentina', 'Australia', 'Austria', 'Belgium', 'Brazil', 'Canada',
#        'Denmark', 'Finland', 'France', 'Germany', 'Ireland', 'Italy',
#        'Japan', 'Mexico', 'Netherlands', 'Norway', 'Poland', 'Portugal',
#        'Singapore', 'Spain', 'Sweden', 'Switzerland', 'UK', 'USA',
#        'Venezuela'], dtype=object)

# %%
q = """
select country from Suppliers
union
select country from Customers
"""

pd.read_sql(q,conn).T
# Out:
#                  0          1        2        3       4       5        6  \
# Country  Argentina  Australia  Austria  Belgium  Brazil  Canada  Denmark
#
#                7       8        9       10     11     12      13           14  \
# Country  Finland  France  Germany  Ireland  Italy  Japan  Mexico  Netherlands
#
#              15      16        17         18     19      20           21  22  \
# Country  Norway  Poland  Portugal  Singapore  Spain  Sweden  Switzerland  UK
#
#           23         24
# Country  USA  Venezuela

# %% [markdown]
# ## 53. Countries with suppliers or customers, version 2
# The employees going on the business trip don’t want
# just a raw list of countries, they want more details.
# We’d like to see output like the below, in the
# Expected Results:
# ```
# SupplierCountry CustomerCountry
# --------------- ---------------
# NULL Argentina
# Australia NULL
# ```

# %%
Suppliers.head(1)
# Out:
#    Id     CompanyName       ContactName        ContactTitle         Address  \
# 0   1  Exotic Liquids  Charlotte Cooper  Purchasing Manager  49 Gilbert St.
#
#      City Region PostalCode Country           Phone   Fax HomePage
# 0  London   None    EC1 4SD      UK  (171) 555-2222  None     None

# %%
Customers.head(1)
# Out:
#       Id          CompanyName   ContactName          ContactTitle  \
# 0  ALFKI  Alfreds Futterkiste  Maria Anders  Sales Representative
#
#          Address    City Region PostalCode  Country        Phone          Fax
# 0  Obere Str. 57  Berlin   None      12209  Germany  030-0074321  030-0076545

# %%
pd.concat([Suppliers.Country.drop_duplicates(),
           Customers.Country.drop_duplicates()]
          ,ignore_index=True,axis=1)\
.rename(columns={0:'SuppliersCountry',1:'CustomersCountry'})\
.sort_values(['SuppliersCountry','CustomersCountry'])
# Out:
#    SuppliersCountry CustomersCountry
# 6         Australia           France
# 9            Brazil           Canada
# 24           Canada              NaN
# 20          Denmark              NaN
# 22          Finland              NaN
# 17           France              NaN
# 10          Germany              NaN
# 13            Italy      Switzerland
# 3             Japan               UK
# 21      Netherlands              NaN
# 14           Norway           Brazil
# 19        Singapore          Austria
# 4             Spain           Sweden
# 8            Sweden              NaN
# 0                UK          Germany
# 1               USA           Mexico
# 11              NaN        Argentina
# 49              NaN          Belgium
# 72              NaN          Denmark
# 86              NaN          Finland
# 36              NaN          Ireland
# 26              NaN            Italy
# 69              NaN           Norway
# 90              NaN           Poland
# ...

# %%
(Suppliers[['Country']]
    .drop_duplicates()
    .set_index('Country',drop=False)
    .sort_index()
    .rename(columns={'Country':'SuppliersCountry'})
    .rename_axis('id')
    .reset_index()
    
    ).head(2)
# Out:
#           id SuppliersCountry
# 0  Australia        Australia
# 1     Brazil           Brazil

# %%
(pd.merge(
(Suppliers[['Country']]
    .drop_duplicates()
    .set_index('Country',drop=False)
    .sort_index()
    .rename(columns={'Country':'SuppliersCountry'})
    .rename_axis('id')
    .reset_index()
    ),
    
(Customers[['Country']]
    .drop_duplicates()
    .set_index('Country',drop=False)
    .sort_index()
    .rename(columns={'Country':'CustomersCountry'})
    .rename_axis('id')
    .reset_index()
    ),

    how='outer')
.sort_values('id').drop('id', axis=1)
 
)
# Out:
#    SuppliersCountry CustomersCountry
# 16              NaN        Argentina
# 0         Australia              NaN
# 17              NaN          Austria
# 18              NaN          Belgium
# 1            Brazil           Brazil
# 2            Canada           Canada
# 3           Denmark          Denmark
# 4           Finland          Finland
# 5            France           France
# 6           Germany          Germany
# 19              NaN          Ireland
# 7             Italy            Italy
# 8             Japan              NaN
# 20              NaN           Mexico
# 9       Netherlands              NaN
# 10           Norway           Norway
# 21              NaN           Poland
# 22              NaN         Portugal
# 11        Singapore              NaN
# 12            Spain            Spain
# 13           Sweden           Sweden
# 23              NaN      Switzerland
# 14               UK               UK
# 15              USA              USA
# ...

# %%
t1 = Suppliers.Country.drop_duplicates()
t2 = Customers.Country.drop_duplicates()

tmp1 = pd.DataFrame({'id':t1, 'supplier_country':t1})
tmp2 = pd.DataFrame({'id':t2, 'customer_country':t2})

result = pd.merge(tmp1,tmp2, how='outer')
result = result.sort_values('id').drop('id', axis=1)
result
# Out:
#    supplier_country customer_country
# 17              NaN        Argentina
# 4         Australia              NaN
# 19              NaN          Austria
# 23              NaN          Belgium
# 6            Brazil           Brazil
# 15           Canada           Canada
# 12          Denmark          Denmark
# 14          Finland          Finland
# 10           France           France
# 7           Germany          Germany
# 22              NaN          Ireland
# 8             Italy            Italy
# 2             Japan              NaN
# 16              NaN           Mexico
# 13      Netherlands              NaN
# 9            Norway           Norway
# 24              NaN           Poland
# 20              NaN         Portugal
# 11        Singapore              NaN
# 3             Spain            Spain
# 5            Sweden           Sweden
# 18              NaN      Switzerland
# 0                UK               UK
# 1               USA              USA
# ...

# %%
q = """

SELECT
  sp.country as suplier_country,
  cp.country as customer_country
  
FROM
(
  SELECT
    country
  FROM
    suppliers
  UNION
  SELECT
    country
  FROM
    customers
) as c

  
LEFT JOIN
( SELECT
    distinct country
  FROM
    suppliers
) as sp


  on c.country = sp.country
  
  
  
LEFT JOIN

(
  SELECT
    distinct country
  FROM
    customers
) as cp
  
  on c.country = cp.country

"""

pd.read_sql(q,conn)
# Out:
#    suplier_country customer_country
# 0             None        Argentina
# 1        Australia             None
# 2             None          Austria
# 3             None          Belgium
# 4           Brazil           Brazil
# 5           Canada           Canada
# 6          Denmark          Denmark
# 7          Finland          Finland
# 8           France           France
# 9          Germany          Germany
# 10            None          Ireland
# 11           Italy            Italy
# 12           Japan             None
# 13            None           Mexico
# 14     Netherlands             None
# 15          Norway           Norway
# 16            None           Poland
# 17            None         Portugal
# 18       Singapore             None
# 19           Spain            Spain
# 20          Sweden           Sweden
# 21            None      Switzerland
# 22              UK               UK
# 23             USA              USA
# 24            None        Venezuela

# %%
# spark.sql(q).show() # spark does not respect order of columns

# %%
q_ms_sql = """
with countries AS (
  SELECT
    country
  FROM
    suppliers
  UNION
  SELECT
    country
  FROM
    customers
), suppliercountry AS (
  SELECT
    distinct country
  FROM
    suppliers
), customercountry AS (
  SELECT
    distinct country
  FROM
    customers
)
SELECT
  sp.country as suplier_country,
  cp.country as customer_country
FROM
  countries c
LEFT JOIN
  suppliercountry sp on c.country = sp.country
LEFT JOIN
  customercountry cp on c.country = cp.country


""";

# %%
q_book = """
;With SupplierCountries as
(Select Distinct Country from Suppliers)
,CustomerCountries as
(Select Distinct Country from Customers)
Select
SupplierCountry = SupplierCountries .Country
,CustomerCountry = CustomerCountries .Country
From SupplierCountries
Full Outer Join CustomerCountries
on CustomerCountries.Country = SupplierCountries.Country

""";

# %%
q_book_good = """


Select
SupplierCountry = SupplierCountries.Country
,CustomerCountry = CustomerCountries.Country

From 
(
Select Distinct Country from Suppliers
) as SupplierCountries



Full Outer Join
(
Select Distinct Country from Customers
) as CustomerCountries

on CustomerCountries.Country = SupplierCountries.Country

""";

pd.read_sql(q,conn)
# Out:
#    suplier_country customer_country
# 0             None        Argentina
# 1        Australia             None
# 2             None          Austria
# 3             None          Belgium
# 4           Brazil           Brazil
# 5           Canada           Canada
# 6          Denmark          Denmark
# 7          Finland          Finland
# 8           France           France
# 9          Germany          Germany
# 10            None          Ireland
# 11           Italy            Italy
# 12           Japan             None
# 13            None           Mexico
# 14     Netherlands             None
# 15          Norway           Norway
# 16            None           Poland
# 17            None         Portugal
# 18       Singapore             None
# 19           Spain            Spain
# 20          Sweden           Sweden
# 21            None      Switzerland
# 22              UK               UK
# 23             USA              USA
# 24            None        Venezuela

# %% [markdown]
# ## 54. Countries with suppliers or customers - version 3
# The output of the above is improved, but it’s still not
# ideal
# What we’d really like to see is the country name, the
# total suppliers, and the total customers.

# %%
Suppliers.head(1)
# Out:
#    Id     CompanyName       ContactName        ContactTitle         Address  \
# 0   1  Exotic Liquids  Charlotte Cooper  Purchasing Manager  49 Gilbert St.
#
#      City Region PostalCode Country           Phone   Fax HomePage
# 0  London   None    EC1 4SD      UK  (171) 555-2222  None     None

# %%
Customers.head(1)
# Out:
#       Id          CompanyName   ContactName          ContactTitle  \
# 0  ALFKI  Alfreds Futterkiste  Maria Anders  Sales Representative
#
#          Address    City Region PostalCode  Country        Phone          Fax
# 0  Obere Str. 57  Berlin   None      12209  Germany  030-0074321  030-0076545

# %%
t1 = Suppliers['Country'].value_counts().rename_axis('Country').rename('TotalSuppliers').reset_index()
t1.head(2)
# Out:
#   Country  TotalSuppliers
# 0     USA               4
# 1  France               3

# %%
t2 = Customers['Country'].value_counts().rename_axis('Country').rename('TotalCustomers').reset_index()

t2.head(2)
# Out:
#    Country  TotalCustomers
# 0      USA              13
# 1  Germany              11

# %%
pd.merge(t1,t2,how='outer').sort_values('Country').fillna(0).set_index("Country").astype(int)
# Out:
#              TotalSuppliers  TotalCustomers
# Country
# Argentina                 0               3
# Australia                 2               0
# Austria                   0               2
# Belgium                   0               2
# Brazil                    1               9
# Canada                    2               3
# Denmark                   1               2
# Finland                   1               2
# France                    3              11
# Germany                   3              11
# Ireland                   0               1
# Italy                     2               3
# Japan                     2               0
# Mexico                    0               5
# Netherlands               1               0
# Norway                    1               1
# Poland                    0               1
# Portugal                  0               2
# Singapore                 1               0
# Spain                     1               5
# ...

# %%
q_ms_sql = """

with countries AS (
  SELECT country FROM suppliers
  UNION
  SELECT country FROM customers
)
SELECT
  c.country,
  coalesce(count(sp.country),0) as totalsupliers,
  coalesce(count(cp.country),0) as totalcustomers
FROM
  countries c
LEFT JOIN
  suppliers sp ON c.country = sp.country
LEFT JOIN
  customers cp ON c.country = cp.country
GROUP BY
  c.country
""";

# %%
q = """

SELECT
  c.country,
  coalesce(count(sp.country),0) as totalsupliers,
  coalesce(count(cp.country),0) as totalcustomers
  
FROM
(
  SELECT country FROM suppliers
  UNION
  SELECT country FROM customers
) as c
  
LEFT JOIN
  suppliers sp ON c.country = sp.country
  
LEFT JOIN
  customers cp ON c.country = cp.country
GROUP BY
  c.country
  
  
""";

pd.read_sql(q,conn)
# Out:
#         country  totalsupliers  totalcustomers
# 0     Argentina              0               3
# 1     Australia              2               0
# 2       Austria              0               2
# 3       Belgium              0               2
# 4        Brazil              9               9
# 5        Canada              6               6
# 6       Denmark              2               2
# 7       Finland              2               2
# 8        France             33              33
# 9       Germany             33              33
# 10      Ireland              0               1
# 11        Italy              6               6
# 12        Japan              2               0
# 13       Mexico              0               5
# 14  Netherlands              1               0
# 15       Norway              1               1
# 16       Poland              0               1
# 17     Portugal              0               2
# 18    Singapore              1               0
# ...

# %%
q_book = """
;With SupplierCountries as
(Select Country , Total = Count(*) from Suppliers group by Country)
,CustomerCountries as
(Select Country , Total = Count(*) from Customers group by Country)
Select
Country = isnull( SupplierCountries.Country,
CustomerCountries.Country)
,TotalSuppliers= isnull(SupplierCountries.Total,0)
,TotalCustomers= isnull(CustomerCountries.Total,0)
From SupplierCountries
Full Outer Join CustomerCountries
on CustomerCountries.Country = SupplierCountries.Country

""";

# %%
q_book_good = """

Select
ifnull(SupplierCountries.Country,
CustomerCountries.Country) as Country

,ifnull(SupplierCountries.Total,0) as TotalSuppliers

,ifnull(CustomerCountries.Total,0) as TotalCustomers

From 
(
Select Country , Total = Count(*) from Suppliers group by Country
) as SupplierCountries


Full Outer Join
( Select Country , Total = Count(*) from Customers group by Country
) as CustomerCountries


on CustomerCountries.Country = SupplierCountries.Country

""";


# pd.read_sql(q_book_good,conn)
# OperationalError: RIGHT and FULL OUTER JOINs are not currently supported
# this might pass in actual sqlite3 but fails in python module.

# %% [markdown]
# ## 55. First order in each country
# Looking at the Orders table—we’d like to show
# details for each order that was the first in that
# particular country, ordered by OrderID.
# So, we need one row per ShipCountry, and
# CustomerID, OrderID, and OrderDate should be of
# the first order from that country.
#
# ```
# Expected Results
# ShipCountry CustomerID OrderID OrderDate
# --------------- ---------- ----------- ----------
# Argentina OCEAN 10409 2015-01-09
# ```

# %%
Orders.head(1)
# Out:
#    orderid customerid  employeeid  orderdate requireddate shippeddate  \
# 0    10248      VINET           5 1996-07-04   1996-08-01  1996-07-16
#
#    shipvia    freight                   shipname         shipaddress shipcity  \
# 0        3  32.380001  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
#
#   shipregion shippostalcode shipcountry
# 0       None          51100      France

# %%
# for given country, orderdate must be the first.

# %%
Orders.groupby('shipcountry').agg(
first_orderdate=('orderdate','first')).head(2)
# Out:
#             first_orderdate
# shipcountry
# Argentina        1997-01-09
# Austria          1996-07-17

# %%
# for a given day, there can be multiple orders.

# %%
(Orders[['shipcountry','customerid', 'orderid', 'orderdate']]
 
.assign(
    first_orderdate = 
        lambda dfx: dfx.groupby('shipcountry'
                           )['orderdate'].transform('first')
)
 
# select only first date
.loc[lambda dfx: dfx.orderdate==dfx.first_orderdate]

# sort
.sort_values(['shipcountry','orderid'])

)
# Out:
#      shipcountry customerid  orderid  orderdate first_orderdate
# 161    Argentina      OCEAN    10409 1997-01-09      1997-01-09
# 10       Austria      ERNSH    10258 1996-07-17      1996-07-17
# 4        Belgium      SUPRD    10252 1996-07-09      1996-07-09
# 2         Brazil      HANAR    10250 1996-07-08      1996-07-08
# 84        Canada      MEREP    10332 1996-10-17      1996-10-17
# 93       Denmark      SIMOB    10341 1996-10-29      1996-10-29
# 18       Finland      WARTH    10266 1996-07-26      1996-07-26
# 0         France      VINET    10248 1996-07-04      1996-07-04
# 1        Germany      TOMSP    10249 1996-07-05      1996-07-05
# 50       Ireland      HUNGO    10298 1996-09-05      1996-09-05
# 27         Italy      MAGAA    10275 1996-08-07      1996-08-07
# 11        Mexico      CENTC    10259 1996-07-18      1996-07-18
# 139       Norway      SANTG    10387 1996-12-18      1996-12-18
# 126       Poland      WOLZA    10374 1996-12-05      1996-12-05
# ...

# %%
q_ms_sql = """
with ranked_orders AS (
  SELECT
    shipcountry,
    customerid,
    orderid,
    orderdate,
    rank() OVER (PARTITION BY shipcountry ORDER BY orderdate) as ranking
  FROM
    orders
)
SELECT
  shipcountry,
  customerid,
  orderid,
  orderdate
FROM
  ranked_orders
WHERE
  ranking = 1
ORDER BY
  shipcountry

""";

# %%
q = """

SELECT
  shipcountry,
  customerid,
  orderid,
  orderdate
  
FROM
(
  SELECT
    shipcountry,
    customerid,
    orderid,
    orderdate,
    rank() OVER (PARTITION BY shipcountry ORDER BY orderdate) as ranking
  FROM
    orders
)
  as ranked_orders
  

WHERE
  ranking = 1
ORDER BY
  shipcountry

""";

pd.read_sql(q,conn)
# Out:
#     shipcountry customerid  orderid   orderdate
# 0     Argentina      OCEAN    10409  1997-01-09
# 1       Austria      ERNSH    10258  1996-07-17
# 2       Belgium      SUPRD    10252  1996-07-09
# 3        Brazil      HANAR    10250  1996-07-08
# 4        Canada      MEREP    10332  1996-10-17
# 5       Denmark      SIMOB    10341  1996-10-29
# 6       Finland      WARTH    10266  1996-07-26
# 7        France      VINET    10248  1996-07-04
# 8       Germany      TOMSP    10249  1996-07-05
# 9       Ireland      HUNGO    10298  1996-09-05
# 10        Italy      MAGAA    10275  1996-08-07
# 11       Mexico      CENTC    10259  1996-07-18
# 12       Norway      SANTG    10387  1996-12-18
# 13       Poland      WOLZA    10374  1996-12-05
# 14     Portugal      FURIB    10328  1996-10-14
# 15        Spain      ROMEY    10281  1996-08-14
# 16       Sweden      FOLKO    10264  1996-07-24
# 17  Switzerland      CHOPS    10254  1996-07-11
# 18           UK      BSBEV    10289  1996-08-26
# ...

# %%
q_book = """
;with OrdersByCountry as
(
Select
ShipCountry
,CustomerID
,OrderID
,OrderDate = convert(date, OrderDate)
,RowNumberPerCountry =
Row_Number()
over (Partition by ShipCountry Order by ShipCountry, OrderID)
From Orders
)
Select
ShipCountry
,CustomerID
,OrderID
,OrderDate
From OrdersByCountry
Where
RowNumberPerCountry = 1
Order by
ShipCountry

""";

# %%
q_book_good = """

Select
ShipCountry
,CustomerID
,OrderID
,OrderDate

From 
(
Select
    ShipCountry
    ,CustomerID
    ,OrderID
    ,OrderDate
    ,(Row_Number() over (Partition by ShipCountry
                          Order by ShipCountry, OrderID)) 
    as RowNumberPerCountry

From Orders
) as OrdersByCountry

Where
RowNumberPerCountry = 1
Order by
ShipCountry

""";

pd.read_sql(q_book_good,conn)
# Out:
#     ShipCountry CustomerID  OrderID   OrderDate
# 0     Argentina      OCEAN    10409  1997-01-09
# 1       Austria      ERNSH    10258  1996-07-17
# 2       Belgium      SUPRD    10252  1996-07-09
# 3        Brazil      HANAR    10250  1996-07-08
# 4        Canada      MEREP    10332  1996-10-17
# 5       Denmark      SIMOB    10341  1996-10-29
# 6       Finland      WARTH    10266  1996-07-26
# 7        France      VINET    10248  1996-07-04
# 8       Germany      TOMSP    10249  1996-07-05
# 9       Ireland      HUNGO    10298  1996-09-05
# 10        Italy      MAGAA    10275  1996-08-07
# 11       Mexico      CENTC    10259  1996-07-18
# 12       Norway      SANTG    10387  1996-12-18
# 13       Poland      WOLZA    10374  1996-12-05
# 14     Portugal      FURIB    10328  1996-10-14
# 15        Spain      ROMEY    10281  1996-08-14
# 16       Sweden      FOLKO    10264  1996-07-24
# 17  Switzerland      CHOPS    10254  1996-07-11
# 18           UK      BSBEV    10289  1996-08-26
# ...

# %%
spark.sql(q).show(2)
# Out:
# +-----------+----------+-------+----------+
# |shipcountry|customerid|orderid| orderdate|
# +-----------+----------+-------+----------+
# |  Argentina|     OCEAN|  10409|1997-01-09|
# |    Austria|     ERNSH|  10258|1996-07-17|
# +-----------+----------+-------+----------+
# only showing top 2 rows

# %% [markdown]
# ## 56. Customers with multiple orders in 5 day period
# There are some customers for whom freight is a
# major expense when ordering from Northwind.
# However, by batching up their orders, and making
# one larger order instead of multiple smaller orders in
# a short period of time, they could reduce their freight
# costs significantly.
# Show those customers who have made more than 1
# order in a 5 day period. The sales people will use this
# to help customers reduce their costs.
# Note: There are more than one way of solving this
# kind of problem. For this problem, we will not be
# using Window functions.
#
# ```
# Expected Result
# CustomerID InitialOrderID InitialOrderDate nextid nextDate
# NextOrderID NextOrderDate DaysBetween
#
#
# cid   iordid idate      nxtid nxtdate    daysBetwn
# ------------------------------------------------
# ANTON 10677 2015-09-22 10682 2015-09-25 3
# AROUT 10741 2015-11-14 10743 2015-11-17 3
# BERGS 10278 2014-08-12 10280 2014-08-14 2
# BERGS 10444 2015-02-12 10445 2015-02-13 1
# BERGS 10866 2016-02-03 10875 2016-02-06 3
#
# ```

# %%
Orders.head(1)
# Out:
#    orderid customerid  employeeid  orderdate requireddate shippeddate  \
# 0    10248      VINET           5 1996-07-04   1996-08-01  1996-07-16
#
#    shipvia    freight                   shipname         shipaddress shipcity  \
# 0        3  32.380001  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
#
#   shipregion shippostalcode shipcountry
# 0       None          51100      France

# %%
(Orders
 
# first sort 
.sort_values(['customerid', 'orderdate'])
 
# new column
.assign(
    daysbetween = lambda dfx: dfx['orderdate'].diff().dt.days
    ) 

# join to itself which is shifted by -1
# NOTE: Here old Orders do not have column daysbetween
.join(Orders.groupby('customerid').shift(-1), 
                      lsuffix='_initial',
                      rsuffix='_next')

# after joining drop unwanted cols
# .drop('daysbetween_initial', axis=1)
 
# filter
# .query('daysbetween_next <= 5 and daysbetween_next >=0')

).head(1)
# Out:
#      orderid_initial customerid  employeeid_initial orderdate_initial  \
# 395            10643      ALFKI                   6        1997-08-25
#
#     requireddate_initial shippeddate_initial  shipvia_initial  \
# 395           1997-09-22          1997-09-02                1
#
#      freight_initial     shipname_initial shipaddress_initial  \
# 395        29.459999  Alfreds Futterkiste       Obere Str. 57
#
#     shipcity_initial shipregion_initial shippostalcode_initial  \
# 395           Berlin               None                  12209
#
#     shipcountry_initial  daysbetween  orderid_next  employeeid_next  \
# 395             Germany          NaN       10692.0              4.0
#
#     orderdate_next requireddate_next shippeddate_next  shipvia_next  \
# 395     1997-10-03        1997-10-31       1997-10-13           2.0
#
#      freight_next         shipname_next shipaddress_next shipcity_next  \
# 395     61.020001  Alfred's Futterkiste    Obere Str. 57        Berlin
#
# ...

# %%
(Orders
 
# first sort 
.sort_values(['customerid', 'orderdate'])
 
# new column
.assign(
    daysbetween = lambda dfx: dfx['orderdate'].diff().dt.days
    ) 

# join to itself which is shifted by -1
# NOTE: We need other dataframe which also has column daysbetween
.pipe(lambda dfx:
      dfx.join(dfx.groupby('customerid').shift(-1), 
                lsuffix='_initial',rsuffix='_next')
      )


# after joining drop unwanted cols
.drop('daysbetween_initial', axis=1)
 
# filter
# .query('daysbetween_next <= 5 and daysbetween_next >=0')
.query(' 0<= daysbetween_next <= 5 ')

).pipe(lambda x: [x.shape, display(x.head())])
# Out:
#      orderid_initial customerid  employeeid_initial orderdate_initial  \
# 429            10677      ANTON                   1        1997-09-22
# 493            10741      AROUT                   4        1997-11-14
# 30             10278      BERGS                   8        1996-08-12
# 196            10444      BERGS                   3        1997-02-12
# 618            10866      BERGS                   5        1998-02-03
#
#     requireddate_initial shippeddate_initial  shipvia_initial  \
# 429           1997-10-20          1997-09-26                3
# 493           1997-11-28          1997-11-18                3
# 30            1996-09-09          1996-08-16                2
# 196           1997-03-12          1997-02-21                3
# 618           1998-03-03          1998-02-12                1
#
#      freight_initial         shipname_initial            shipaddress_initial  \
# 429         4.030000  Antonio Moreno Taquería                Mataderos  2312
# ...

# %%
# first sort 
Orders = Orders.sort_values(['customerid', 'orderdate'])
 
# new column
Orders['daysbetween'] = Orders['orderdate'].diff().dt.days

# join to itself which is shifted by -1
ans = Orders.join(
    Orders.groupby('customerid').shift(-1), 
    lsuffix='_initial',rsuffix='_next')
      

# after joining drop unwanted cols
ans = ans.drop('daysbetween_initial', axis=1)
 
# filter
ans.query('daysbetween_next <= 5 and daysbetween_next >=0').tail(2)
# Out:
#      orderid_initial customerid  employeeid_initial orderdate_initial  \
# 445            10693      WHITC                   3        1997-10-06
# 625            10873      WILMK                   4        1998-02-06
#
#     requireddate_initial shippeddate_initial  shipvia_initial  \
# 445           1997-10-20          1997-10-10                3
# 625           1998-03-06          1998-02-09                1
#
#      freight_initial      shipname_initial  shipaddress_initial  \
# 445       139.339996  White Clover Markets  1029 - 12th Ave. S.
# 625         0.820000           Wilman Kala        Keskuskatu 45
#
#     shipcity_initial shipregion_initial shippostalcode_initial  \
# 445          Seattle                 WA                  98124
# 625         Helsinki               None                  21240
#
#     shipcountry_initial  orderid_next  employeeid_next orderdate_next  \
# 445                 USA       10696.0              8.0     1997-10-08
# ...

# %%
q = """
SELECT
  initial_order.customerid,
  initial_order.orderid as initial_order_id,
  initial_order.orderdate as initial_order_date,
  next_order.orderid as nextorderid,
  next_order.orderdate as nextorderdate,
  
  cast ( (JulianDay(next_order.orderdate) - 
          JulianDay(initial_order.orderdate)
          ) as int
  ) as daysbetween


FROM
  orders initial_order
INNER JOIN
  orders next_order on initial_order.customerid = next_order.customerid
WHERE
  initial_order.orderid < next_order.orderid
  AND ( JulianDay(next_order.orderdate) - 
        JulianDay(initial_order.orderdate)
      ) <= 5

""";
pd.read_sql(q,conn).head(7).style.highlight_max(subset='daysbetween')
# Out:
# <style  type="text/css" >
#     #T_f8803052_6bca_11ea_bb6f_acde48001122row5_col5 {
#             background-color:  yellow;
#         }</style><table id="T_f8803052_6bca_11ea_bb6f_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >customerid</th>        <th class="col_heading level0 col1" >initial_order_id</th>        <th class="col_heading level0 col2" >initial_order_date</th>        <th class="col_heading level0 col3" >nextorderid</th>        <th class="col_heading level0 col4" >nextorderdate</th>        <th class="col_heading level0 col5" >daysbetween</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f8803052_6bca_11ea_bb6f_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f8803052_6bca_11ea_bb6f_acde48001122row0_col0" class="data row0 col0" >HANAR</td>
# ...

# %%
datetime(1996,10,1) - datetime(1996,9,26)
# Out:
# datetime.timedelta(days=5)

# %%
# customer ISLAT has bought at least twice within 5 days of
# 1996-09-26 to 1996-10-01

# %%
q_ms_sql = """
Select
InitialOrder.CustomerID
,InitialOrderID = InitialOrder.OrderID
,InitialOrderDate = convert(date, InitialOrder.OrderDate)
,NextOrderID = NextOrder.OrderID
,NextOrderDate = convert(date, NextOrder.OrderDate)
,DaysBetween = datediff(dd, InitialOrder.OrderDate,
NextOrder.OrderDate)
from Orders InitialOrder
join Orders NextOrder
on InitialOrder.CustomerID = NextOrder.CustomerID
where
InitialOrder.OrderID < NextOrder.OrderID
and datediff(dd, InitialOrder.OrderDate, NextOrder.OrderDate) <= 5
Order by
InitialOrder.CustomerID
,InitialOrder.OrderID

""";

# %%
q = """
SELECT
  initial_order.customerid,
  initial_order.orderid as initial_order_id,
  initial_order.orderdate as initial_order_date,
  next_order.orderid as nextorderid,
  next_order.orderdate as nextorderdate,
  
  cast ( (JulianDay(next_order.orderdate) - 
          JulianDay(initial_order.orderdate)
          ) as int
  ) as daysbetween


FROM
  orders initial_order
INNER JOIN
  orders next_order on initial_order.customerid = next_order.customerid
WHERE
  initial_order.orderid < next_order.orderid
  AND ( JulianDay(next_order.orderdate) - 
        JulianDay(initial_order.orderdate)
      ) <= 5

""";

# spark.sql(q).show()
# there is no JulianDay in pyspark.sql

# %% [markdown]
# ## 57. Customers with multiple orders in 5 day period, version 2
# There’s another way of solving the problem above,
# using Window functions. We would like to see the
# following results.

# %%
q_ms_sql = """
WITH customer_orders AS (
  SELECT
    customerid,
    orderid as initial_order_id,
    orderdate as initial_order_date,
    LEAD (o.orderdate, 1) OVER ( PARTITION BY customerid ORDER BY orderdate) AS next_order_date
  FROM
    orders o
  ORDER BY
    o.customerid, o.orderdate
)
SELECT
  *,
  (co.next_order_date - co.initial_order_date) as daysbetween
FROM
  customer_orders co
WHERE
  (co.next_order_date - co.initial_order_date) <= 5
""";

# %%
q = """
SELECT
  *,
  cast( ( JulianDay(co.next_order_date) -
          JulianDay(co.initial_order_date)
      ) as int
  ) as daysbetween
  
FROM
(
  SELECT
    customerid,
    orderid as initial_order_id,
    orderdate as initial_order_date,
    LEAD (o.orderdate, 1) OVER ( PARTITION BY customerid ORDER BY orderdate) AS next_order_date
  FROM
    orders o
  ORDER BY
    o.customerid, o.orderdate
)

  as co
WHERE
  ( JulianDay(co.next_order_date) - 
    JulianDay(co.initial_order_date)
  ) <= 5
""";

pd.read_sql(q,conn).pipe(lambda x: [x.shape, display(x.head())])
# Out:
#   customerid  initial_order_id initial_order_date next_order_date  daysbetween
# 0      ANTON             10677         1997-09-22      1997-09-25            3
# 1      AROUT             10741         1997-11-14      1997-11-17            3
# 2      BERGS             10278         1996-08-12      1996-08-14            2
# 3      BERGS             10444         1997-02-12      1997-02-13            1
# 4      BERGS             10866         1998-02-03      1998-02-06            3
# [(69, 5), None]

# %% [markdown]
# # Time Taken

# %%
time_taken = time.time() - time_start_notebook
h,m = divmod(time_taken,60*60)
print('Time taken: {:.0f} hr {:.0f} min {:.0f} secs'.format(h, *divmod(m,60)))
# Out:
# Time taken: 0 hr 0 min 42 secs
